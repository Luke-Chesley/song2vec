# %%
import argparse
import math
import os
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, List, Optional, Union

import datasets
import torch
from accelerate import Accelerator
from accelerate.logging import get_logger
from datasets import DatasetDict, concatenate_datasets, load_dataset
from huggingface_hub import HfApi
from torch.utils.data.dataloader import DataLoader
from tqdm.auto import tqdm

import transformers
from transformers import (
    AdamW,
    SchedulerType,
    get_scheduler,
    is_wandb_available,
    set_seed,
)
from model import (
    Wav2Vec2ForPreTraining,
    Wav2Vec2Config,
    Wav2Vec2FeatureEncoder
)

from transformers.models.wav2vec2.modeling_wav2vec2 import _compute_mask_indices, _sample_negative_indices
from transformers.utils import send_example_telemetry

# %%
@dataclass
class DataCollatorForWav2Vec2Pretraining:


    model: Wav2Vec2ForPreTraining
    feature_extractor: Wav2Vec2FeatureEncoder
    padding: Union[bool, str] = "longest"
    pad_to_multiple_of: Optional[int] = None
    mask_time_prob: Optional[float] = 0.65
    mask_time_length: Optional[int] = 10

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # reformat list to dict and set to pytorch format

        input_values = [feature['input_values'][0] for feature in features]  # Note the [0] to get the tensor from the list

        # Wrap input_values in a dictionary
        inputs_dict = {'input_values': input_values}


        batch = self.feature_extractor.pad(
            inputs_dict,
            padding=self.padding,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )

        device = batch["input_values"].device
        batch_size = batch["input_values"].shape[0]

        mask_indices_seq_length = self.model._get_feat_extract_output_lengths(batch["input_values"].shape[-1])
        # make sure masked sequence length is a Python scalar
        mask_indices_seq_length = int(mask_indices_seq_length)

        # make sure that no loss is computed on padded inputs
        if batch.get("attention_mask") is not None:
            # compute real output lengths according to convolution formula
            batch["sub_attention_mask"] = self.model._get_feature_vector_attention_mask(
                mask_indices_seq_length, batch["attention_mask"]
            )

        features_shape = (batch_size, mask_indices_seq_length)

        # sample randomly masked indices
        mask_time_indices = _compute_mask_indices(
            features_shape,
            self.mask_time_prob,
            self.mask_time_length,
            attention_mask=batch.get("sub_attention_mask"),
        )

        # sample negative indices
        sampled_negative_indices = _sample_negative_indices(
            features_shape,
            self.model.config.num_negatives,
            mask_time_indices=mask_time_indices,
        )
        batch["mask_time_indices"] = torch.tensor(mask_time_indices, dtype=torch.long, device=device)
        batch["sampled_negative_indices"] = torch.tensor(sampled_negative_indices, dtype=torch.long, device=device)

        return batch


def multiply_grads(params, c):
    """Multiplies grads by a constant *c*."""
    for p in params:
        if p.grad is not None:
            if torch.is_tensor(c):
                c = c.to(p.grad.device)
            p.grad.data.mul_(c)


def get_grad_norm(params, scale=1):
    """Compute grad norm given a gradient scale."""
    total_norm = 0.0
    for p in params:
        if p.grad is not None:
            param_norm = (p.grad.detach().data / scale).norm(2)
            total_norm += param_norm.item() ** 2
    total_norm = total_norm**0.5
    return total_norm

# %%
accelerator = Accelerator()

# %%
set_seed(0)

# %%
from dataset import AudioDataset
import random

parent_dir = 'data/mp3_train_files'
file_list = [os.path.join(root, file) 
             for root, _, files in os.walk(parent_dir) 
             for file in files]

random.seed(42)
random.shuffle(file_list)

train_size = int(0.8 * len(file_list))
val_size = int(0.1 * len(file_list))
test_size = len(file_list) - train_size - val_size

train_files = file_list[:train_size]
val_files = file_list[train_size:train_size + val_size]
test_files = file_list[train_size + val_size:]

train_dataset = AudioDataset(train_files)
val_dataset = AudioDataset(val_files)
test_dataset = AudioDataset(test_files)

# %%
config = Wav2Vec2Config()
feature_extractor = Wav2Vec2FeatureEncoder()

# %%
model = Wav2Vec2ForPreTraining(config)

mask_time_prob = config.mask_time_prob
mask_time_length = config.mask_time_length

# %%
data_collator = DataCollatorForWav2Vec2Pretraining(
        model=model,
        feature_extractor=feature_extractor,
        #pad_to_multiple_of=args.pad_to_multiple_of,
        mask_time_prob=mask_time_prob,
        mask_time_length=mask_time_length,
    )

train_dataloader = DataLoader(
        train_dataset,
        shuffle=True,
        collate_fn=data_collator,
        batch_size=8,
    )

eval_dataloader = DataLoader(
        val_dataset, collate_fn=data_collator, batch_size=8
    )

optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=5e-5,
        betas=[0.9, 0.999],
        eps=1e-8,
    )

model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
        model, optimizer, train_dataloader, eval_dataloader
    )

# %%
num_update_steps_per_epoch = math.ceil(len(train_dataloader) / 1)
max_train_steps = 3 * num_update_steps_per_epoch

lr_scheduler = get_scheduler(
        name='linear',
        optimizer=optimizer,
        num_warmup_steps=0,
        num_training_steps=max_train_steps,
    )

num_train_epochs = math.ceil(max_train_steps / num_update_steps_per_epoch)

# %%
total_batch_size = 8 * accelerator.num_processes * 1
max_gumbel_temperature = 2.0
min_gumbel_temperature = 0.5
gumbel_temperature_decay = 0.999995
logging_steps = 10
gradient_accumulation_steps = 1
saving_steps = 500
push_to_hub = False
output_dir = 'weights'

# %%
from torch.utils.tensorboard import SummaryWriter

log_dir = "runs/1"  # Change this to your desired log directory
writer = SummaryWriter(log_dir=log_dir)

# %%
progress_bar = tqdm(range(max_train_steps), disable=not accelerator.is_local_main_process)
completed_steps = 0
starting_epoch = 0

for epoch in range(starting_epoch,num_train_epochs):
    model.train()
   # batch_iterator = tqdm(train_dataloader, desc=f"Processing Epoch {epoch:02d}")
    for step,batch in enumerate(train_dataloader):

        num_losses = batch["mask_time_indices"].sum()
        sub_attention_mask = batch.pop('sub_attention_mask',None)
        sub_attention_mask = (
                sub_attention_mask if sub_attention_mask is not None else torch.ones_like(batch["mask_time_indices"])
            )
        percent_masked = num_losses / sub_attention_mask.sum()

        outputs = model(**batch)

        loss = outputs.loss
        accelerator.backward(loss)

        multiply_grads(model.parameters(), 1 / num_losses)

        if (step + 1) % 1 == 0 or step == len(train_dataloader) - 1:
            # compute grad norm for monitoring
            scale = (
                accelerator.scaler._scale.item()
                if hasattr(accelerator, "scaler") and accelerator.scaler is not None
                else 1
            )

            grad_norm = get_grad_norm(model.parameters(), scale)

            optimizer.step()
            optimizer.zero_grad()

            if not accelerator.optimizer_step_was_skipped:
                lr_scheduler.step()
            elif accelerator.is_local_main_process:
                progress_bar.write(
                            f"Gradients have overflown - skipping update step... Updating gradient scale to {scale}..."
                        )
            
            # update gumbel temperature
            gumbel_temperature = max(
                        max_gumbel_temperature * gumbel_temperature_decay**completed_steps,
                        min_gumbel_temperature,
                )
            if hasattr(model, "module"):
                    model.module.set_gumbel_temperature(gumbel_temperature)
            else:
                    model.set_gumbel_temperature(gumbel_temperature)

            progress_bar.update(1)
            completed_steps += 1

        if (step + 1) % (1 * logging_steps) == 0:
            loss.detach()
            outputs.contrastive_loss.detach()
            outputs.diversity_loss.detach()

            train_logs = {
                    "loss": (loss * gradient_accumulation_steps) / num_losses,
                    "constrast_loss": outputs.contrastive_loss / num_losses,
                    "div_loss": outputs.diversity_loss / num_losses,
                    "%_mask_idx": percent_masked / accelerator.num_processes,
                    "ppl": outputs.codevector_perplexity,
                    "lr": torch.tensor(optimizer.param_groups[0]["lr"]),
                    "temp": torch.tensor(gumbel_temperature),
                    "grad_norm": torch.tensor(grad_norm),
            }
            log_str = ""
            for k, v in train_logs.items():
                log_str += "| {}: {:.3e}".format(k, v.item())

            if accelerator.is_local_main_process:
                progress_bar.write(log_str)
                for k, v in train_logs.items():
                    writer.add_scalar(f'train/{k}', v.item(), completed_steps)
        
        if (step + 1) % (gradient_accumulation_steps * saving_steps) == 0:
            if (push_to_hub and epoch < num_train_epochs - 1) or output_dir is not None:
                accelerator.wait_for_everyone()
                unwrapped_model = accelerator.unwrap_model(model)
                unwrapped_model.save_pretrained(
                    output_dir, is_main_process=accelerator.is_main_process, save_function=accelerator.save
                )

        if completed_steps >= max_train_steps:
                break
        

    # 7. Validate!

    model.eval()

    # init logs
    val_logs = {
        "val_loss": 0,
        "val_contrastive_loss": 0,
        "val_diversity_loss": 0,
        "val_num_losses": 0,
    }
    for step, batch in enumerate(eval_dataloader):
        with torch.no_grad():
            batch.pop("sub_attention_mask", None)
            outputs = model(**batch)

        val_logs["val_loss"] += outputs.loss
        val_logs["val_contrastive_loss"] += outputs.contrastive_loss
        val_logs["val_diversity_loss"] += outputs.diversity_loss
        val_logs["val_num_losses"] += batch["mask_time_indices"].sum()

    # sum over devices in multi-processing
    if accelerator.num_processes > 1:
        val_logs = {k: accelerator.gather_for_metrics(v).sum() for k, v in val_logs.items()}

    val_logs = {k: v / val_logs["val_num_losses"] for k, v in val_logs.items()}

    log_str = ""
    for k, v in val_logs.items():
        log_str += "| {}: {:.3e}".format(k, v.item())

    if accelerator.is_local_main_process:
        progress_bar.write(log_str)
        # Log validation metrics to TensorBoard
        for k, v in val_logs.items():
            writer.add_scalar(f'val/{k}', v.item(), epoch)
        
    if output_dir is not None:
        accelerator.wait_for_everyone()
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(
            output_dir, is_main_process=accelerator.is_main_process, save_function=accelerator.save
        )

        

                
writer.close()
# Out:
#   0%|          | 0/4650 [00:00<?, ?it/s]
# | loss: 4.723e+00| constrast_loss: 4.635e+00| div_loss: 8.764e-01| %_mask_idx: 4.016e-02| ppl: 7.908e+01| lr: 4.989e-05| temp: 2.000e+00| grad_norm: 3.050e+00
# | loss: 4.707e+00| constrast_loss: 4.619e+00| div_loss: 8.826e-01| %_mask_idx: 4.016e-02| ppl: 7.513e+01| lr: 4.978e-05| temp: 2.000e+00| grad_norm: 2.339e+00
# | loss: 4.720e+00| constrast_loss: 4.630e+00| div_loss: 8.972e-01| %_mask_idx: 4.016e-02| ppl: 6.580e+01| lr: 4.968e-05| temp: 2.000e+00| grad_norm: 2.109e+00
# | loss: 4.710e+00| constrast_loss: 4.621e+00| div_loss: 8.884e-01| %_mask_idx: 4.016e-02| ppl: 7.141e+01| lr: 4.957e-05| temp: 2.000e+00| grad_norm: 1.851e+00
# | loss: 4.708e+00| constrast_loss: 4.623e+00| div_loss: 8.594e-01| %_mask_idx: 4.016e-02| ppl: 8.997e+01| lr: 4.946e-05| temp: 2.000e+00| grad_norm: 1.409e+00
# | loss: 4.704e+00| constrast_loss: 4.618e+00| div_loss: 8.528e-01| %_mask_idx: 4.016e-02| ppl: 9.424e+01| lr: 4.935e-05| temp: 1.999e+00| grad_norm: 1.576e+00
# | loss: 4.704e+00| constrast_loss: 4.619e+00| div_loss: 8.526e-01| %_mask_idx: 4.016e-02| ppl: 9.432e+01| lr: 4.925e-05| temp: 1.999e+00| grad_norm: 1.444e+00
# | loss: 4.709e+00| constrast_loss: 4.625e+00| div_loss: 8.382e-01| %_mask_idx: 4.016e-02| ppl: 1.036e+02| lr: 4.914e-05| temp: 1.999e+00| grad_norm: 1.399e+00
# | loss: 4.695e+00| constrast_loss: 4.611e+00| div_loss: 8.401e-01| %_mask_idx: 4.016e-02| ppl: 1.023e+02| lr: 4.903e-05| temp: 1.999e+00| grad_norm: 1.614e+00
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.554e-01| %_mask_idx: 7.580e-02| ppl: 1.566e+02| lr: 4.892e-05| temp: 1.999e+00| grad_norm: 1.033e+00
# | loss: 4.705e+00| constrast_loss: 4.620e+00| div_loss: 8.519e-01| %_mask_idx: 4.016e-02| ppl: 9.480e+01| lr: 4.882e-05| temp: 1.999e+00| grad_norm: 1.477e+00
# | loss: 4.687e+00| constrast_loss: 4.610e+00| div_loss: 7.727e-01| %_mask_idx: 8.032e-02| ppl: 1.454e+02| lr: 4.871e-05| temp: 1.999e+00| grad_norm: 1.033e+00
# | loss: 4.685e+00| constrast_loss: 4.601e+00| div_loss: 8.330e-01| %_mask_idx: 4.016e-02| ppl: 1.069e+02| lr: 4.860e-05| temp: 1.999e+00| grad_norm: 1.303e+00
# | loss: 4.696e+00| constrast_loss: 4.621e+00| div_loss: 7.512e-01| %_mask_idx: 7.831e-02| ppl: 1.592e+02| lr: 4.849e-05| temp: 1.999e+00| grad_norm: 1.112e+00
# | loss: 4.695e+00| constrast_loss: 4.615e+00| div_loss: 7.993e-01| %_mask_idx: 4.016e-02| ppl: 1.285e+02| lr: 4.839e-05| temp: 1.999e+00| grad_norm: 1.473e+00
# | loss: 4.689e+00| constrast_loss: 4.618e+00| div_loss: 7.082e-01| %_mask_idx: 8.032e-02| ppl: 1.867e+02| lr: 4.828e-05| temp: 1.998e+00| grad_norm: 8.988e-01
# | loss: 4.697e+00| constrast_loss: 4.617e+00| div_loss: 8.021e-01| %_mask_idx: 4.016e-02| ppl: 1.267e+02| lr: 4.817e-05| temp: 1.998e+00| grad_norm: 1.347e+00
# | loss: 4.685e+00| constrast_loss: 4.616e+00| div_loss: 6.983e-01| %_mask_idx: 7.681e-02| ppl: 1.931e+02| lr: 4.806e-05| temp: 1.998e+00| grad_norm: 8.255e-01
# | loss: 4.692e+00| constrast_loss: 4.612e+00| div_loss: 7.996e-01| %_mask_idx: 4.016e-02| ppl: 1.282e+02| lr: 4.796e-05| temp: 1.998e+00| grad_norm: 1.058e+00
# | loss: 4.693e+00| constrast_loss: 4.614e+00| div_loss: 7.853e-01| %_mask_idx: 4.016e-02| ppl: 1.374e+02| lr: 4.785e-05| temp: 1.998e+00| grad_norm: 1.593e+00
# | loss: 4.698e+00| constrast_loss: 4.618e+00| div_loss: 7.993e-01| %_mask_idx: 4.016e-02| ppl: 1.284e+02| lr: 4.774e-05| temp: 1.998e+00| grad_norm: 1.356e+00
# | loss: 4.695e+00| constrast_loss: 4.613e+00| div_loss: 8.249e-01| %_mask_idx: 4.016e-02| ppl: 1.121e+02| lr: 4.763e-05| temp: 1.998e+00| grad_norm: 1.385e+00
# | loss: 4.699e+00| constrast_loss: 4.618e+00| div_loss: 8.125e-01| %_mask_idx: 4.016e-02| ppl: 1.200e+02| lr: 4.753e-05| temp: 1.998e+00| grad_norm: 1.221e+00
# | loss: 4.693e+00| constrast_loss: 4.614e+00| div_loss: 7.956e-01| %_mask_idx: 4.016e-02| ppl: 1.308e+02| lr: 4.742e-05| temp: 1.998e+00| grad_norm: 1.179e+00
# | loss: 4.691e+00| constrast_loss: 4.618e+00| div_loss: 7.235e-01| %_mask_idx: 7.681e-02| ppl: 1.770e+02| lr: 4.731e-05| temp: 1.998e+00| grad_norm: 9.125e-01
# | loss: 4.686e+00| constrast_loss: 4.607e+00| div_loss: 7.922e-01| %_mask_idx: 4.016e-02| ppl: 1.330e+02| lr: 4.720e-05| temp: 1.997e+00| grad_norm: 1.234e+00
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.832e-01| %_mask_idx: 4.016e-02| ppl: 1.388e+02| lr: 4.710e-05| temp: 1.997e+00| grad_norm: 1.079e+00
# | loss: 4.699e+00| constrast_loss: 4.619e+00| div_loss: 8.028e-01| %_mask_idx: 4.016e-02| ppl: 1.262e+02| lr: 4.699e-05| temp: 1.997e+00| grad_norm: 1.069e+00
# | loss: 4.681e+00| constrast_loss: 4.615e+00| div_loss: 6.618e-01| %_mask_idx: 8.032e-02| ppl: 2.165e+02| lr: 4.688e-05| temp: 1.997e+00| grad_norm: 9.711e-01
# | loss: 4.692e+00| constrast_loss: 4.621e+00| div_loss: 7.139e-01| %_mask_idx: 7.580e-02| ppl: 1.831e+02| lr: 4.677e-05| temp: 1.997e+00| grad_norm: 1.125e+00
# | loss: 4.698e+00| constrast_loss: 4.618e+00| div_loss: 8.074e-01| %_mask_idx: 4.016e-02| ppl: 1.233e+02| lr: 4.667e-05| temp: 1.997e+00| grad_norm: 8.807e-01
# | loss: 4.702e+00| constrast_loss: 4.621e+00| div_loss: 8.130e-01| %_mask_idx: 4.016e-02| ppl: 1.197e+02| lr: 4.656e-05| temp: 1.997e+00| grad_norm: 1.028e+00
# | loss: 4.704e+00| constrast_loss: 4.626e+00| div_loss: 7.821e-01| %_mask_idx: 4.016e-02| ppl: 1.395e+02| lr: 4.645e-05| temp: 1.997e+00| grad_norm: 1.383e+00
# | loss: 4.694e+00| constrast_loss: 4.614e+00| div_loss: 7.963e-01| %_mask_idx: 4.016e-02| ppl: 1.304e+02| lr: 4.634e-05| temp: 1.997e+00| grad_norm: 1.139e+00
# | loss: 4.700e+00| constrast_loss: 4.617e+00| div_loss: 8.263e-01| %_mask_idx: 4.016e-02| ppl: 1.112e+02| lr: 4.624e-05| temp: 1.997e+00| grad_norm: 1.025e+00
# | loss: 4.695e+00| constrast_loss: 4.617e+00| div_loss: 7.776e-01| %_mask_idx: 4.016e-02| ppl: 1.423e+02| lr: 4.613e-05| temp: 1.996e+00| grad_norm: 1.052e+00
# | loss: 4.696e+00| constrast_loss: 4.617e+00| div_loss: 7.824e-01| %_mask_idx: 4.016e-02| ppl: 1.393e+02| lr: 4.602e-05| temp: 1.996e+00| grad_norm: 1.129e+00
# | loss: 4.678e+00| constrast_loss: 4.610e+00| div_loss: 6.796e-01| %_mask_idx: 4.016e-02| ppl: 2.051e+02| lr: 4.591e-05| temp: 1.996e+00| grad_norm: 1.104e+00
# | loss: 4.699e+00| constrast_loss: 4.621e+00| div_loss: 7.754e-01| %_mask_idx: 4.016e-02| ppl: 1.438e+02| lr: 4.581e-05| temp: 1.996e+00| grad_norm: 1.259e+00
# | loss: 4.690e+00| constrast_loss: 4.622e+00| div_loss: 6.742e-01| %_mask_idx: 8.032e-02| ppl: 2.085e+02| lr: 4.570e-05| temp: 1.996e+00| grad_norm: 8.062e-01
# | loss: 4.696e+00| constrast_loss: 4.615e+00| div_loss: 8.057e-01| %_mask_idx: 4.016e-02| ppl: 1.243e+02| lr: 4.559e-05| temp: 1.996e+00| grad_norm: 1.010e+00
# | loss: 4.684e+00| constrast_loss: 4.615e+00| div_loss: 6.898e-01| %_mask_idx: 8.032e-02| ppl: 1.985e+02| lr: 4.548e-05| temp: 1.996e+00| grad_norm: 8.584e-01
# | loss: 4.689e+00| constrast_loss: 4.612e+00| div_loss: 7.736e-01| %_mask_idx: 4.016e-02| ppl: 1.449e+02| lr: 4.538e-05| temp: 1.996e+00| grad_norm: 1.016e+00
# | loss: 4.689e+00| constrast_loss: 4.609e+00| div_loss: 8.007e-01| %_mask_idx: 4.016e-02| ppl: 1.275e+02| lr: 4.527e-05| temp: 1.996e+00| grad_norm: 9.427e-01
# | loss: 4.678e+00| constrast_loss: 4.622e+00| div_loss: 5.614e-01| %_mask_idx: 8.032e-02| ppl: 2.807e+02| lr: 4.516e-05| temp: 1.996e+00| grad_norm: 9.192e-01
# | loss: 4.694e+00| constrast_loss: 4.615e+00| div_loss: 7.876e-01| %_mask_idx: 4.016e-02| ppl: 1.359e+02| lr: 4.505e-05| temp: 1.995e+00| grad_norm: 1.149e+00
# | loss: 4.684e+00| constrast_loss: 4.610e+00| div_loss: 7.358e-01| %_mask_idx: 4.016e-02| ppl: 1.691e+02| lr: 4.495e-05| temp: 1.995e+00| grad_norm: 8.651e-01
# | loss: 4.697e+00| constrast_loss: 4.618e+00| div_loss: 7.896e-01| %_mask_idx: 4.016e-02| ppl: 1.347e+02| lr: 4.484e-05| temp: 1.995e+00| grad_norm: 1.106e+00
# | loss: 4.688e+00| constrast_loss: 4.618e+00| div_loss: 6.951e-01| %_mask_idx: 7.480e-02| ppl: 1.951e+02| lr: 4.473e-05| temp: 1.995e+00| grad_norm: 8.397e-01
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.884e-01| %_mask_idx: 4.016e-02| ppl: 1.354e+02| lr: 4.462e-05| temp: 1.995e+00| grad_norm: 1.119e+00
# | loss: 4.687e+00| constrast_loss: 4.617e+00| div_loss: 6.971e-01| %_mask_idx: 7.882e-02| ppl: 1.938e+02| lr: 4.452e-05| temp: 1.995e+00| grad_norm: 7.482e-01
# | loss: 4.690e+00| constrast_loss: 4.611e+00| div_loss: 7.892e-01| %_mask_idx: 4.016e-02| ppl: 1.349e+02| lr: 4.441e-05| temp: 1.995e+00| grad_norm: 1.072e+00
# | loss: 4.687e+00| constrast_loss: 4.609e+00| div_loss: 7.778e-01| %_mask_idx: 4.016e-02| ppl: 1.422e+02| lr: 4.430e-05| temp: 1.995e+00| grad_norm: 9.865e-01
# | loss: 4.687e+00| constrast_loss: 4.610e+00| div_loss: 7.635e-01| %_mask_idx: 4.016e-02| ppl: 1.513e+02| lr: 4.419e-05| temp: 1.995e+00| grad_norm: 1.071e+00
# | loss: 4.701e+00| constrast_loss: 4.623e+00| div_loss: 7.854e-01| %_mask_idx: 4.016e-02| ppl: 1.373e+02| lr: 4.409e-05| temp: 1.995e+00| grad_norm: 1.153e+00
# | loss: 4.701e+00| constrast_loss: 4.621e+00| div_loss: 7.975e-01| %_mask_idx: 4.016e-02| ppl: 1.296e+02| lr: 4.398e-05| temp: 1.994e+00| grad_norm: 1.002e+00
# | loss: 4.696e+00| constrast_loss: 4.618e+00| div_loss: 7.804e-01| %_mask_idx: 4.016e-02| ppl: 1.405e+02| lr: 4.387e-05| temp: 1.994e+00| grad_norm: 9.092e-01
# | loss: 4.683e+00| constrast_loss: 4.614e+00| div_loss: 6.916e-01| %_mask_idx: 8.032e-02| ppl: 1.974e+02| lr: 4.376e-05| temp: 1.994e+00| grad_norm: 7.561e-01
# | loss: 4.694e+00| constrast_loss: 4.615e+00| div_loss: 7.931e-01| %_mask_idx: 4.016e-02| ppl: 1.324e+02| lr: 4.366e-05| temp: 1.994e+00| grad_norm: 9.136e-01
# | loss: 4.685e+00| constrast_loss: 4.615e+00| div_loss: 6.973e-01| %_mask_idx: 4.016e-02| ppl: 1.937e+02| lr: 4.355e-05| temp: 1.994e+00| grad_norm: 1.019e+00
# | loss: 4.688e+00| constrast_loss: 4.615e+00| div_loss: 7.314e-01| %_mask_idx: 4.016e-02| ppl: 1.719e+02| lr: 4.344e-05| temp: 1.994e+00| grad_norm: 9.799e-01
# | loss: 4.697e+00| constrast_loss: 4.617e+00| div_loss: 7.994e-01| %_mask_idx: 4.016e-02| ppl: 1.284e+02| lr: 4.333e-05| temp: 1.994e+00| grad_norm: 8.558e-01
# | loss: 4.695e+00| constrast_loss: 4.617e+00| div_loss: 7.798e-01| %_mask_idx: 4.016e-02| ppl: 1.410e+02| lr: 4.323e-05| temp: 1.994e+00| grad_norm: 1.061e+00
# | loss: 4.698e+00| constrast_loss: 4.614e+00| div_loss: 8.404e-01| %_mask_idx: 4.016e-02| ppl: 1.021e+02| lr: 4.312e-05| temp: 1.994e+00| grad_norm: 8.220e-01
# | loss: 4.685e+00| constrast_loss: 4.618e+00| div_loss: 6.750e-01| %_mask_idx: 8.032e-02| ppl: 2.080e+02| lr: 4.301e-05| temp: 1.994e+00| grad_norm: 7.517e-01
# | loss: 4.695e+00| constrast_loss: 4.617e+00| div_loss: 7.843e-01| %_mask_idx: 4.016e-02| ppl: 1.380e+02| lr: 4.290e-05| temp: 1.993e+00| grad_norm: 1.015e+00
# | loss: 4.690e+00| constrast_loss: 4.616e+00| div_loss: 7.379e-01| %_mask_idx: 4.016e-02| ppl: 1.677e+02| lr: 4.280e-05| temp: 1.993e+00| grad_norm: 9.670e-01
# | loss: 4.696e+00| constrast_loss: 4.618e+00| div_loss: 7.809e-01| %_mask_idx: 4.016e-02| ppl: 1.402e+02| lr: 4.269e-05| temp: 1.993e+00| grad_norm: 9.482e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.725e-01| %_mask_idx: 4.016e-02| ppl: 1.456e+02| lr: 4.258e-05| temp: 1.993e+00| grad_norm: 9.691e-01
# | loss: 4.701e+00| constrast_loss: 4.623e+00| div_loss: 7.770e-01| %_mask_idx: 4.016e-02| ppl: 1.427e+02| lr: 4.247e-05| temp: 1.993e+00| grad_norm: 8.788e-01
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.781e-01| %_mask_idx: 4.016e-02| ppl: 1.420e+02| lr: 4.237e-05| temp: 1.993e+00| grad_norm: 9.648e-01
# | loss: 4.690e+00| constrast_loss: 4.611e+00| div_loss: 7.914e-01| %_mask_idx: 4.016e-02| ppl: 1.335e+02| lr: 4.226e-05| temp: 1.993e+00| grad_norm: 8.689e-01
# | loss: 4.697e+00| constrast_loss: 4.618e+00| div_loss: 7.913e-01| %_mask_idx: 4.016e-02| ppl: 1.336e+02| lr: 4.215e-05| temp: 1.993e+00| grad_norm: 9.449e-01
# | loss: 4.693e+00| constrast_loss: 4.613e+00| div_loss: 8.003e-01| %_mask_idx: 4.016e-02| ppl: 1.278e+02| lr: 4.204e-05| temp: 1.993e+00| grad_norm: 8.297e-01
# | loss: 4.692e+00| constrast_loss: 4.613e+00| div_loss: 7.842e-01| %_mask_idx: 4.016e-02| ppl: 1.381e+02| lr: 4.194e-05| temp: 1.993e+00| grad_norm: 9.814e-01
# | loss: 4.695e+00| constrast_loss: 4.617e+00| div_loss: 7.819e-01| %_mask_idx: 4.016e-02| ppl: 1.396e+02| lr: 4.183e-05| temp: 1.992e+00| grad_norm: 9.018e-01
# | loss: 4.700e+00| constrast_loss: 4.622e+00| div_loss: 7.872e-01| %_mask_idx: 4.016e-02| ppl: 1.362e+02| lr: 4.172e-05| temp: 1.992e+00| grad_norm: 8.987e-01
# | loss: 4.687e+00| constrast_loss: 4.607e+00| div_loss: 8.057e-01| %_mask_idx: 4.016e-02| ppl: 1.243e+02| lr: 4.161e-05| temp: 1.992e+00| grad_norm: 8.879e-01
# | loss: 4.695e+00| constrast_loss: 4.619e+00| div_loss: 7.681e-01| %_mask_idx: 4.016e-02| ppl: 1.484e+02| lr: 4.151e-05| temp: 1.992e+00| grad_norm: 8.124e-01
# | loss: 4.693e+00| constrast_loss: 4.614e+00| div_loss: 7.935e-01| %_mask_idx: 4.016e-02| ppl: 1.322e+02| lr: 4.140e-05| temp: 1.992e+00| grad_norm: 8.772e-01
# | loss: 4.678e+00| constrast_loss: 4.611e+00| div_loss: 6.702e-01| %_mask_idx: 7.932e-02| ppl: 2.111e+02| lr: 4.129e-05| temp: 1.992e+00| grad_norm: 7.443e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.859e-01| %_mask_idx: 4.016e-02| ppl: 1.370e+02| lr: 4.118e-05| temp: 1.992e+00| grad_norm: 1.081e+00
# | loss: 4.699e+00| constrast_loss: 4.621e+00| div_loss: 7.837e-01| %_mask_idx: 4.016e-02| ppl: 1.384e+02| lr: 4.108e-05| temp: 1.992e+00| grad_norm: 1.036e+00
# | loss: 4.681e+00| constrast_loss: 4.614e+00| div_loss: 6.676e-01| %_mask_idx: 7.882e-02| ppl: 2.127e+02| lr: 4.097e-05| temp: 1.992e+00| grad_norm: 7.579e-01
# | loss: 4.688e+00| constrast_loss: 4.610e+00| div_loss: 7.866e-01| %_mask_idx: 4.016e-02| ppl: 1.366e+02| lr: 4.086e-05| temp: 1.992e+00| grad_norm: 7.783e-01
# | loss: 4.686e+00| constrast_loss: 4.620e+00| div_loss: 6.594e-01| %_mask_idx: 8.032e-02| ppl: 2.180e+02| lr: 4.075e-05| temp: 1.991e+00| grad_norm: 7.879e-01
# | loss: 4.697e+00| constrast_loss: 4.620e+00| div_loss: 7.729e-01| %_mask_idx: 4.016e-02| ppl: 1.453e+02| lr: 4.065e-05| temp: 1.991e+00| grad_norm: 7.679e-01
# | loss: 4.683e+00| constrast_loss: 4.617e+00| div_loss: 6.615e-01| %_mask_idx: 7.580e-02| ppl: 2.166e+02| lr: 4.054e-05| temp: 1.991e+00| grad_norm: 7.414e-01
# | loss: 4.689e+00| constrast_loss: 4.609e+00| div_loss: 7.996e-01| %_mask_idx: 4.016e-02| ppl: 1.283e+02| lr: 4.043e-05| temp: 1.991e+00| grad_norm: 9.795e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.732e-01| %_mask_idx: 4.016e-02| ppl: 1.452e+02| lr: 4.032e-05| temp: 1.991e+00| grad_norm: 9.909e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.813e-01| %_mask_idx: 4.016e-02| ppl: 1.399e+02| lr: 4.022e-05| temp: 1.991e+00| grad_norm: 8.791e-01
# | loss: 4.680e+00| constrast_loss: 4.615e+00| div_loss: 6.492e-01| %_mask_idx: 8.032e-02| ppl: 2.245e+02| lr: 4.011e-05| temp: 1.991e+00| grad_norm: 7.041e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.682e-01| %_mask_idx: 4.016e-02| ppl: 1.484e+02| lr: 4.000e-05| temp: 1.991e+00| grad_norm: 9.023e-01
# | loss: 4.676e+00| constrast_loss: 4.609e+00| div_loss: 6.675e-01| %_mask_idx: 8.032e-02| ppl: 2.128e+02| lr: 3.989e-05| temp: 1.991e+00| grad_norm: 7.188e-01
# | loss: 4.681e+00| constrast_loss: 4.613e+00| div_loss: 6.844e-01| %_mask_idx: 4.016e-02| ppl: 2.020e+02| lr: 3.978e-05| temp: 1.991e+00| grad_norm: 9.437e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.545e-01| %_mask_idx: 4.016e-02| ppl: 1.571e+02| lr: 3.968e-05| temp: 1.990e+00| grad_norm: 1.057e+00
# | loss: 4.689e+00| constrast_loss: 4.610e+00| div_loss: 7.900e-01| %_mask_idx: 4.016e-02| ppl: 1.344e+02| lr: 3.957e-05| temp: 1.990e+00| grad_norm: 8.618e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.590e-01| %_mask_idx: 4.016e-02| ppl: 1.543e+02| lr: 3.946e-05| temp: 1.990e+00| grad_norm: 9.412e-01
# | loss: 4.697e+00| constrast_loss: 4.619e+00| div_loss: 7.831e-01| %_mask_idx: 4.016e-02| ppl: 1.388e+02| lr: 3.935e-05| temp: 1.990e+00| grad_norm: 8.010e-01
# | loss: 4.693e+00| constrast_loss: 4.614e+00| div_loss: 7.857e-01| %_mask_idx: 4.016e-02| ppl: 1.371e+02| lr: 3.925e-05| temp: 1.990e+00| grad_norm: 7.746e-01
# | loss: 4.677e+00| constrast_loss: 4.613e+00| div_loss: 6.356e-01| %_mask_idx: 7.982e-02| ppl: 2.332e+02| lr: 3.914e-05| temp: 1.990e+00| grad_norm: 7.824e-01
# | loss: 4.694e+00| constrast_loss: 4.615e+00| div_loss: 7.840e-01| %_mask_idx: 4.016e-02| ppl: 1.382e+02| lr: 3.903e-05| temp: 1.990e+00| grad_norm: 8.563e-01
# | loss: 4.693e+00| constrast_loss: 4.616e+00| div_loss: 7.649e-01| %_mask_idx: 4.016e-02| ppl: 1.505e+02| lr: 3.892e-05| temp: 1.990e+00| grad_norm: 8.742e-01
# | loss: 4.680e+00| constrast_loss: 4.615e+00| div_loss: 6.457e-01| %_mask_idx: 7.731e-02| ppl: 2.267e+02| lr: 3.882e-05| temp: 1.990e+00| grad_norm: 7.161e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.703e-01| %_mask_idx: 4.016e-02| ppl: 1.470e+02| lr: 3.871e-05| temp: 1.990e+00| grad_norm: 8.744e-01
# | loss: 4.678e+00| constrast_loss: 4.614e+00| div_loss: 6.386e-01| %_mask_idx: 7.831e-02| ppl: 2.313e+02| lr: 3.860e-05| temp: 1.989e+00| grad_norm: 7.013e-01
# | loss: 4.696e+00| constrast_loss: 4.616e+00| div_loss: 7.990e-01| %_mask_idx: 4.016e-02| ppl: 1.286e+02| lr: 3.849e-05| temp: 1.989e+00| grad_norm: 8.749e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.695e-01| %_mask_idx: 4.016e-02| ppl: 1.475e+02| lr: 3.839e-05| temp: 1.989e+00| grad_norm: 7.652e-01
# | loss: 4.681e+00| constrast_loss: 4.616e+00| div_loss: 6.479e-01| %_mask_idx: 7.781e-02| ppl: 2.254e+02| lr: 3.828e-05| temp: 1.989e+00| grad_norm: 6.907e-01
# | loss: 4.679e+00| constrast_loss: 4.615e+00| div_loss: 6.408e-01| %_mask_idx: 7.982e-02| ppl: 2.299e+02| lr: 3.817e-05| temp: 1.989e+00| grad_norm: 7.196e-01
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.725e-01| %_mask_idx: 4.016e-02| ppl: 1.456e+02| lr: 3.806e-05| temp: 1.989e+00| grad_norm: 8.020e-01
# | loss: 4.693e+00| constrast_loss: 4.616e+00| div_loss: 7.740e-01| %_mask_idx: 4.016e-02| ppl: 1.447e+02| lr: 3.796e-05| temp: 1.989e+00| grad_norm: 8.702e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.668e-01| %_mask_idx: 4.016e-02| ppl: 1.492e+02| lr: 3.785e-05| temp: 1.989e+00| grad_norm: 6.942e-01
# | loss: 4.682e+00| constrast_loss: 4.616e+00| div_loss: 6.537e-01| %_mask_idx: 8.032e-02| ppl: 2.216e+02| lr: 3.774e-05| temp: 1.989e+00| grad_norm: 7.017e-01
# | loss: 4.678e+00| constrast_loss: 4.614e+00| div_loss: 6.304e-01| %_mask_idx: 8.032e-02| ppl: 2.366e+02| lr: 3.763e-05| temp: 1.989e+00| grad_norm: 8.387e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.719e-01| %_mask_idx: 4.016e-02| ppl: 1.460e+02| lr: 3.753e-05| temp: 1.988e+00| grad_norm: 7.639e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.510e-01| %_mask_idx: 4.016e-02| ppl: 1.594e+02| lr: 3.742e-05| temp: 1.988e+00| grad_norm: 8.155e-01
# | loss: 4.686e+00| constrast_loss: 4.608e+00| div_loss: 7.871e-01| %_mask_idx: 4.016e-02| ppl: 1.363e+02| lr: 3.731e-05| temp: 1.988e+00| grad_norm: 9.964e-01
# | loss: 4.682e+00| constrast_loss: 4.615e+00| div_loss: 6.724e-01| %_mask_idx: 4.016e-02| ppl: 2.097e+02| lr: 3.720e-05| temp: 1.988e+00| grad_norm: 7.673e-01
# | loss: 4.687e+00| constrast_loss: 4.611e+00| div_loss: 7.599e-01| %_mask_idx: 4.016e-02| ppl: 1.536e+02| lr: 3.710e-05| temp: 1.988e+00| grad_norm: 7.205e-01
# | loss: 4.691e+00| constrast_loss: 4.612e+00| div_loss: 7.845e-01| %_mask_idx: 4.016e-02| ppl: 1.379e+02| lr: 3.699e-05| temp: 1.988e+00| grad_norm: 8.858e-01
# | loss: 4.688e+00| constrast_loss: 4.611e+00| div_loss: 7.770e-01| %_mask_idx: 4.016e-02| ppl: 1.427e+02| lr: 3.688e-05| temp: 1.988e+00| grad_norm: 6.741e-01
# | loss: 4.691e+00| constrast_loss: 4.612e+00| div_loss: 7.818e-01| %_mask_idx: 4.016e-02| ppl: 1.396e+02| lr: 3.677e-05| temp: 1.988e+00| grad_norm: 8.437e-01
# | loss: 4.694e+00| constrast_loss: 4.615e+00| div_loss: 7.841e-01| %_mask_idx: 4.016e-02| ppl: 1.382e+02| lr: 3.667e-05| temp: 1.988e+00| grad_norm: 1.032e+00
# | loss: 4.685e+00| constrast_loss: 4.608e+00| div_loss: 7.695e-01| %_mask_idx: 4.016e-02| ppl: 1.475e+02| lr: 3.656e-05| temp: 1.988e+00| grad_norm: 8.722e-01
# | loss: 4.685e+00| constrast_loss: 4.619e+00| div_loss: 6.591e-01| %_mask_idx: 7.530e-02| ppl: 2.182e+02| lr: 3.645e-05| temp: 1.987e+00| grad_norm: 6.765e-01
# | loss: 4.678e+00| constrast_loss: 4.615e+00| div_loss: 6.384e-01| %_mask_idx: 8.032e-02| ppl: 2.314e+02| lr: 3.634e-05| temp: 1.987e+00| grad_norm: 7.386e-01
# | loss: 4.674e+00| constrast_loss: 4.612e+00| div_loss: 6.271e-01| %_mask_idx: 8.032e-02| ppl: 2.387e+02| lr: 3.624e-05| temp: 1.987e+00| grad_norm: 8.611e-01
# | loss: 4.684e+00| constrast_loss: 4.608e+00| div_loss: 7.661e-01| %_mask_idx: 4.016e-02| ppl: 1.497e+02| lr: 3.613e-05| temp: 1.987e+00| grad_norm: 7.976e-01
# | loss: 4.687e+00| constrast_loss: 4.611e+00| div_loss: 7.649e-01| %_mask_idx: 4.016e-02| ppl: 1.505e+02| lr: 3.602e-05| temp: 1.987e+00| grad_norm: 8.048e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.668e-01| %_mask_idx: 4.016e-02| ppl: 1.493e+02| lr: 3.591e-05| temp: 1.987e+00| grad_norm: 8.743e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.513e-01| %_mask_idx: 4.016e-02| ppl: 1.592e+02| lr: 3.581e-05| temp: 1.987e+00| grad_norm: 7.102e-01
# | loss: 4.689e+00| constrast_loss: 4.612e+00| div_loss: 7.741e-01| %_mask_idx: 4.016e-02| ppl: 1.446e+02| lr: 3.570e-05| temp: 1.987e+00| grad_norm: 1.029e+00
# | loss: 4.692e+00| constrast_loss: 4.613e+00| div_loss: 7.899e-01| %_mask_idx: 4.016e-02| ppl: 1.344e+02| lr: 3.559e-05| temp: 1.987e+00| grad_norm: 8.155e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.672e-01| %_mask_idx: 4.016e-02| ppl: 1.490e+02| lr: 3.548e-05| temp: 1.987e+00| grad_norm: 8.601e-01
# | loss: 4.681e+00| constrast_loss: 4.614e+00| div_loss: 6.663e-01| %_mask_idx: 6.978e-02| ppl: 2.136e+02| lr: 3.538e-05| temp: 1.986e+00| grad_norm: 6.816e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.564e-01| %_mask_idx: 4.016e-02| ppl: 1.559e+02| lr: 3.527e-05| temp: 1.986e+00| grad_norm: 9.530e-01
# | loss: 4.684e+00| constrast_loss: 4.620e+00| div_loss: 6.338e-01| %_mask_idx: 8.032e-02| ppl: 2.344e+02| lr: 3.516e-05| temp: 1.986e+00| grad_norm: 7.409e-01
# | loss: 4.683e+00| constrast_loss: 4.605e+00| div_loss: 7.790e-01| %_mask_idx: 4.016e-02| ppl: 1.414e+02| lr: 3.505e-05| temp: 1.986e+00| grad_norm: 7.723e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.775e-01| %_mask_idx: 4.016e-02| ppl: 1.424e+02| lr: 3.495e-05| temp: 1.986e+00| grad_norm: 9.202e-01
# | loss: 4.685e+00| constrast_loss: 4.606e+00| div_loss: 7.877e-01| %_mask_idx: 4.016e-02| ppl: 1.359e+02| lr: 3.484e-05| temp: 1.986e+00| grad_norm: 8.909e-01
# | loss: 4.680e+00| constrast_loss: 4.617e+00| div_loss: 6.299e-01| %_mask_idx: 7.580e-02| ppl: 2.369e+02| lr: 3.473e-05| temp: 1.986e+00| grad_norm: 7.336e-01
# | loss: 4.691e+00| constrast_loss: 4.612e+00| div_loss: 7.947e-01| %_mask_idx: 4.016e-02| ppl: 1.314e+02| lr: 3.462e-05| temp: 1.986e+00| grad_norm: 6.345e-01
# | loss: 4.688e+00| constrast_loss: 4.614e+00| div_loss: 7.397e-01| %_mask_idx: 4.016e-02| ppl: 1.666e+02| lr: 3.452e-05| temp: 1.986e+00| grad_norm: 8.670e-01
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.822e-01| %_mask_idx: 4.016e-02| ppl: 1.394e+02| lr: 3.441e-05| temp: 1.986e+00| grad_norm: 7.567e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.769e-01| %_mask_idx: 4.016e-02| ppl: 1.428e+02| lr: 3.430e-05| temp: 1.985e+00| grad_norm: 5.912e-01
# | loss: 4.676e+00| constrast_loss: 4.615e+00| div_loss: 6.078e-01| %_mask_idx: 7.781e-02| ppl: 2.510e+02| lr: 3.419e-05| temp: 1.985e+00| grad_norm: 7.938e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.658e-01| %_mask_idx: 4.016e-02| ppl: 1.499e+02| lr: 3.409e-05| temp: 1.985e+00| grad_norm: 8.751e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.598e-01| %_mask_idx: 4.016e-02| ppl: 1.538e+02| lr: 3.398e-05| temp: 1.985e+00| grad_norm: 7.746e-01
# | loss: 4.681e+00| constrast_loss: 4.617e+00| div_loss: 6.452e-01| %_mask_idx: 7.731e-02| ppl: 2.271e+02| lr: 3.387e-05| temp: 1.985e+00| grad_norm: 7.429e-01
# | loss: 4.676e+00| constrast_loss: 4.604e+00| div_loss: 7.158e-01| %_mask_idx: 4.016e-02| ppl: 1.819e+02| lr: 3.376e-05| temp: 1.985e+00| grad_norm: 7.231e-01
# | loss: 4.683e+00| constrast_loss: 4.605e+00| div_loss: 7.735e-01| %_mask_idx: 4.016e-02| ppl: 1.450e+02| lr: 3.366e-05| temp: 1.985e+00| grad_norm: 8.912e-01
# | loss: 4.688e+00| constrast_loss: 4.609e+00| div_loss: 7.852e-01| %_mask_idx: 4.016e-02| ppl: 1.375e+02| lr: 3.355e-05| temp: 1.985e+00| grad_norm: 8.216e-01
# | loss: 4.679e+00| constrast_loss: 4.600e+00| div_loss: 7.887e-01| %_mask_idx: 4.016e-02| ppl: 1.352e+02| lr: 3.344e-05| temp: 1.985e+00| grad_norm: 7.013e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.759e-01| %_mask_idx: 4.016e-02| ppl: 1.434e+02| lr: 3.333e-05| temp: 1.985e+00| grad_norm: 7.259e-01
# | val_loss: 4.681e+00| val_contrastive_loss: 4.605e+00| val_diversity_loss: 7.566e-01| val_num_losses: 1.000e+00
# | loss: 4.697e+00| constrast_loss: 4.620e+00| div_loss: 7.697e-01| %_mask_idx: 4.016e-02| ppl: 1.474e+02| lr: 3.323e-05| temp: 1.984e+00| grad_norm: 8.457e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.513e-01| %_mask_idx: 4.016e-02| ppl: 1.591e+02| lr: 3.312e-05| temp: 1.984e+00| grad_norm: 7.744e-01
# | loss: 4.695e+00| constrast_loss: 4.618e+00| div_loss: 7.725e-01| %_mask_idx: 4.016e-02| ppl: 1.456e+02| lr: 3.301e-05| temp: 1.984e+00| grad_norm: 7.867e-01
# | loss: 4.698e+00| constrast_loss: 4.623e+00| div_loss: 7.545e-01| %_mask_idx: 4.016e-02| ppl: 1.571e+02| lr: 3.290e-05| temp: 1.984e+00| grad_norm: 1.042e+00
# | loss: 4.689e+00| constrast_loss: 4.611e+00| div_loss: 7.754e-01| %_mask_idx: 4.016e-02| ppl: 1.438e+02| lr: 3.280e-05| temp: 1.984e+00| grad_norm: 7.398e-01
# | loss: 4.693e+00| constrast_loss: 4.615e+00| div_loss: 7.783e-01| %_mask_idx: 4.016e-02| ppl: 1.419e+02| lr: 3.269e-05| temp: 1.984e+00| grad_norm: 8.720e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.685e-01| %_mask_idx: 4.016e-02| ppl: 1.482e+02| lr: 3.258e-05| temp: 1.984e+00| grad_norm: 7.477e-01
# | loss: 4.698e+00| constrast_loss: 4.621e+00| div_loss: 7.673e-01| %_mask_idx: 4.016e-02| ppl: 1.489e+02| lr: 3.247e-05| temp: 1.984e+00| grad_norm: 8.171e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.616e-01| %_mask_idx: 4.016e-02| ppl: 1.525e+02| lr: 3.237e-05| temp: 1.984e+00| grad_norm: 7.433e-01
# | loss: 4.679e+00| constrast_loss: 4.615e+00| div_loss: 6.361e-01| %_mask_idx: 7.781e-02| ppl: 2.329e+02| lr: 3.226e-05| temp: 1.984e+00| grad_norm: 7.286e-01
# | loss: 4.697e+00| constrast_loss: 4.620e+00| div_loss: 7.703e-01| %_mask_idx: 4.016e-02| ppl: 1.470e+02| lr: 3.215e-05| temp: 1.983e+00| grad_norm: 7.382e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.871e-01| %_mask_idx: 4.016e-02| ppl: 1.363e+02| lr: 3.204e-05| temp: 1.983e+00| grad_norm: 8.783e-01
# | loss: 4.686e+00| constrast_loss: 4.610e+00| div_loss: 7.638e-01| %_mask_idx: 4.016e-02| ppl: 1.512e+02| lr: 3.194e-05| temp: 1.983e+00| grad_norm: 7.741e-01
# | loss: 4.680e+00| constrast_loss: 4.614e+00| div_loss: 6.587e-01| %_mask_idx: 8.032e-02| ppl: 2.184e+02| lr: 3.183e-05| temp: 1.983e+00| grad_norm: 7.582e-01
# | loss: 4.698e+00| constrast_loss: 4.620e+00| div_loss: 7.746e-01| %_mask_idx: 4.016e-02| ppl: 1.443e+02| lr: 3.172e-05| temp: 1.983e+00| grad_norm: 7.651e-01
# | loss: 4.700e+00| constrast_loss: 4.623e+00| div_loss: 7.737e-01| %_mask_idx: 4.016e-02| ppl: 1.448e+02| lr: 3.161e-05| temp: 1.983e+00| grad_norm: 7.095e-01
# | loss: 4.695e+00| constrast_loss: 4.617e+00| div_loss: 7.799e-01| %_mask_idx: 4.016e-02| ppl: 1.409e+02| lr: 3.151e-05| temp: 1.983e+00| grad_norm: 7.494e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.497e-01| %_mask_idx: 4.016e-02| ppl: 1.602e+02| lr: 3.140e-05| temp: 1.983e+00| grad_norm: 8.027e-01
# | loss: 4.696e+00| constrast_loss: 4.618e+00| div_loss: 7.794e-01| %_mask_idx: 4.016e-02| ppl: 1.412e+02| lr: 3.129e-05| temp: 1.983e+00| grad_norm: 7.587e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.728e-01| %_mask_idx: 4.016e-02| ppl: 1.454e+02| lr: 3.118e-05| temp: 1.983e+00| grad_norm: 7.419e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.787e-01| %_mask_idx: 4.016e-02| ppl: 1.416e+02| lr: 3.108e-05| temp: 1.982e+00| grad_norm: 8.761e-01
# | loss: 4.679e+00| constrast_loss: 4.602e+00| div_loss: 7.659e-01| %_mask_idx: 4.016e-02| ppl: 1.498e+02| lr: 3.097e-05| temp: 1.982e+00| grad_norm: 7.076e-01
# | loss: 4.673e+00| constrast_loss: 4.614e+00| div_loss: 5.917e-01| %_mask_idx: 7.982e-02| ppl: 2.613e+02| lr: 3.086e-05| temp: 1.982e+00| grad_norm: 7.649e-01
# | loss: 4.676e+00| constrast_loss: 4.613e+00| div_loss: 6.361e-01| %_mask_idx: 7.631e-02| ppl: 2.329e+02| lr: 3.075e-05| temp: 1.982e+00| grad_norm: 7.550e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.832e-01| %_mask_idx: 4.016e-02| ppl: 1.387e+02| lr: 3.065e-05| temp: 1.982e+00| grad_norm: 8.482e-01
# | loss: 4.681e+00| constrast_loss: 4.617e+00| div_loss: 6.327e-01| %_mask_idx: 8.032e-02| ppl: 2.351e+02| lr: 3.054e-05| temp: 1.982e+00| grad_norm: 6.755e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.722e-01| %_mask_idx: 4.016e-02| ppl: 1.458e+02| lr: 3.043e-05| temp: 1.982e+00| grad_norm: 5.933e-01
# | loss: 4.678e+00| constrast_loss: 4.613e+00| div_loss: 6.490e-01| %_mask_idx: 7.430e-02| ppl: 2.246e+02| lr: 3.032e-05| temp: 1.982e+00| grad_norm: 6.965e-01
# | loss: 4.678e+00| constrast_loss: 4.613e+00| div_loss: 6.469e-01| %_mask_idx: 8.032e-02| ppl: 2.260e+02| lr: 3.022e-05| temp: 1.982e+00| grad_norm: 6.771e-01
# | loss: 4.678e+00| constrast_loss: 4.600e+00| div_loss: 7.882e-01| %_mask_idx: 4.016e-02| ppl: 1.356e+02| lr: 3.011e-05| temp: 1.982e+00| grad_norm: 7.328e-01
# | loss: 4.685e+00| constrast_loss: 4.616e+00| div_loss: 6.966e-01| %_mask_idx: 4.016e-02| ppl: 1.942e+02| lr: 3.000e-05| temp: 1.981e+00| grad_norm: 8.219e-01
# | loss: 4.692e+00| constrast_loss: 4.614e+00| div_loss: 7.762e-01| %_mask_idx: 4.016e-02| ppl: 1.432e+02| lr: 2.989e-05| temp: 1.981e+00| grad_norm: 8.113e-01
# | loss: 4.695e+00| constrast_loss: 4.619e+00| div_loss: 7.625e-01| %_mask_idx: 4.016e-02| ppl: 1.520e+02| lr: 2.978e-05| temp: 1.981e+00| grad_norm: 7.836e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.645e-01| %_mask_idx: 4.016e-02| ppl: 1.507e+02| lr: 2.968e-05| temp: 1.981e+00| grad_norm: 8.916e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.525e-01| %_mask_idx: 4.016e-02| ppl: 1.584e+02| lr: 2.957e-05| temp: 1.981e+00| grad_norm: 8.425e-01
# | loss: 4.678e+00| constrast_loss: 4.614e+00| div_loss: 6.389e-01| %_mask_idx: 8.032e-02| ppl: 2.311e+02| lr: 2.946e-05| temp: 1.981e+00| grad_norm: 6.341e-01
# | loss: 4.680e+00| constrast_loss: 4.613e+00| div_loss: 6.672e-01| %_mask_idx: 4.016e-02| ppl: 2.130e+02| lr: 2.935e-05| temp: 1.981e+00| grad_norm: 8.765e-01
# | loss: 4.679e+00| constrast_loss: 4.617e+00| div_loss: 6.128e-01| %_mask_idx: 8.032e-02| ppl: 2.478e+02| lr: 2.925e-05| temp: 1.981e+00| grad_norm: 8.066e-01
# | loss: 4.695e+00| constrast_loss: 4.620e+00| div_loss: 7.547e-01| %_mask_idx: 4.016e-02| ppl: 1.570e+02| lr: 2.914e-05| temp: 1.981e+00| grad_norm: 7.192e-01
# | loss: 4.690e+00| constrast_loss: 4.612e+00| div_loss: 7.805e-01| %_mask_idx: 4.016e-02| ppl: 1.405e+02| lr: 2.903e-05| temp: 1.981e+00| grad_norm: 7.211e-01
# | loss: 4.679e+00| constrast_loss: 4.616e+00| div_loss: 6.331e-01| %_mask_idx: 8.032e-02| ppl: 2.348e+02| lr: 2.892e-05| temp: 1.981e+00| grad_norm: 7.004e-01
# | loss: 4.676e+00| constrast_loss: 4.613e+00| div_loss: 6.349e-01| %_mask_idx: 7.681e-02| ppl: 2.337e+02| lr: 2.882e-05| temp: 1.980e+00| grad_norm: 6.907e-01
# | loss: 4.692e+00| constrast_loss: 4.617e+00| div_loss: 7.508e-01| %_mask_idx: 4.016e-02| ppl: 1.595e+02| lr: 2.871e-05| temp: 1.980e+00| grad_norm: 8.063e-01
# | loss: 4.678e+00| constrast_loss: 4.618e+00| div_loss: 6.041e-01| %_mask_idx: 8.032e-02| ppl: 2.534e+02| lr: 2.860e-05| temp: 1.980e+00| grad_norm: 7.587e-01
# | loss: 4.690e+00| constrast_loss: 4.614e+00| div_loss: 7.584e-01| %_mask_idx: 4.016e-02| ppl: 1.546e+02| lr: 2.849e-05| temp: 1.980e+00| grad_norm: 8.511e-01
# | loss: 4.681e+00| constrast_loss: 4.616e+00| div_loss: 6.558e-01| %_mask_idx: 7.631e-02| ppl: 2.203e+02| lr: 2.839e-05| temp: 1.980e+00| grad_norm: 6.737e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.700e-01| %_mask_idx: 4.016e-02| ppl: 1.472e+02| lr: 2.828e-05| temp: 1.980e+00| grad_norm: 8.154e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.505e-01| %_mask_idx: 4.016e-02| ppl: 1.597e+02| lr: 2.817e-05| temp: 1.980e+00| grad_norm: 7.758e-01
# | loss: 4.694e+00| constrast_loss: 4.616e+00| div_loss: 7.746e-01| %_mask_idx: 4.016e-02| ppl: 1.442e+02| lr: 2.806e-05| temp: 1.980e+00| grad_norm: 8.178e-01
# | loss: 4.693e+00| constrast_loss: 4.616e+00| div_loss: 7.712e-01| %_mask_idx: 4.016e-02| ppl: 1.464e+02| lr: 2.796e-05| temp: 1.980e+00| grad_norm: 7.619e-01
# | loss: 4.693e+00| constrast_loss: 4.618e+00| div_loss: 7.453e-01| %_mask_idx: 4.016e-02| ppl: 1.630e+02| lr: 2.785e-05| temp: 1.980e+00| grad_norm: 7.772e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.729e-01| %_mask_idx: 4.016e-02| ppl: 1.453e+02| lr: 2.774e-05| temp: 1.979e+00| grad_norm: 7.847e-01
# | loss: 4.692e+00| constrast_loss: 4.614e+00| div_loss: 7.854e-01| %_mask_idx: 4.016e-02| ppl: 1.373e+02| lr: 2.763e-05| temp: 1.979e+00| grad_norm: 8.782e-01
# | loss: 4.681e+00| constrast_loss: 4.615e+00| div_loss: 6.589e-01| %_mask_idx: 7.681e-02| ppl: 2.183e+02| lr: 2.753e-05| temp: 1.979e+00| grad_norm: 6.616e-01
# | loss: 4.682e+00| constrast_loss: 4.617e+00| div_loss: 6.502e-01| %_mask_idx: 7.631e-02| ppl: 2.239e+02| lr: 2.742e-05| temp: 1.979e+00| grad_norm: 6.507e-01
# | loss: 4.693e+00| constrast_loss: 4.616e+00| div_loss: 7.693e-01| %_mask_idx: 4.016e-02| ppl: 1.476e+02| lr: 2.731e-05| temp: 1.979e+00| grad_norm: 6.185e-01
# | loss: 4.678e+00| constrast_loss: 4.614e+00| div_loss: 6.352e-01| %_mask_idx: 8.032e-02| ppl: 2.335e+02| lr: 2.720e-05| temp: 1.979e+00| grad_norm: 6.835e-01
# | loss: 4.693e+00| constrast_loss: 4.617e+00| div_loss: 7.591e-01| %_mask_idx: 4.016e-02| ppl: 1.542e+02| lr: 2.710e-05| temp: 1.979e+00| grad_norm: 8.169e-01
# | loss: 4.696e+00| constrast_loss: 4.620e+00| div_loss: 7.623e-01| %_mask_idx: 4.016e-02| ppl: 1.521e+02| lr: 2.699e-05| temp: 1.979e+00| grad_norm: 7.278e-01
# | loss: 4.684e+00| constrast_loss: 4.609e+00| div_loss: 7.527e-01| %_mask_idx: 4.016e-02| ppl: 1.583e+02| lr: 2.688e-05| temp: 1.979e+00| grad_norm: 6.740e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.566e-01| %_mask_idx: 4.016e-02| ppl: 1.558e+02| lr: 2.677e-05| temp: 1.979e+00| grad_norm: 7.176e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.778e-01| %_mask_idx: 4.016e-02| ppl: 1.422e+02| lr: 2.667e-05| temp: 1.978e+00| grad_norm: 7.002e-01
# | loss: 4.686e+00| constrast_loss: 4.607e+00| div_loss: 7.897e-01| %_mask_idx: 4.016e-02| ppl: 1.346e+02| lr: 2.656e-05| temp: 1.978e+00| grad_norm: 6.270e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.691e-01| %_mask_idx: 4.016e-02| ppl: 1.478e+02| lr: 2.645e-05| temp: 1.978e+00| grad_norm: 7.747e-01
# | loss: 4.676e+00| constrast_loss: 4.615e+00| div_loss: 6.086e-01| %_mask_idx: 8.032e-02| ppl: 2.505e+02| lr: 2.634e-05| temp: 1.978e+00| grad_norm: 6.465e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.495e-01| %_mask_idx: 4.016e-02| ppl: 1.603e+02| lr: 2.624e-05| temp: 1.978e+00| grad_norm: 9.117e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.667e-01| %_mask_idx: 4.016e-02| ppl: 1.493e+02| lr: 2.613e-05| temp: 1.978e+00| grad_norm: 8.406e-01
# | loss: 4.672e+00| constrast_loss: 4.611e+00| div_loss: 6.065e-01| %_mask_idx: 8.032e-02| ppl: 2.518e+02| lr: 2.602e-05| temp: 1.978e+00| grad_norm: 7.980e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.663e-01| %_mask_idx: 4.016e-02| ppl: 1.496e+02| lr: 2.591e-05| temp: 1.978e+00| grad_norm: 7.481e-01
# | loss: 4.687e+00| constrast_loss: 4.609e+00| div_loss: 7.753e-01| %_mask_idx: 4.016e-02| ppl: 1.438e+02| lr: 2.581e-05| temp: 1.978e+00| grad_norm: 6.655e-01
# | loss: 4.674e+00| constrast_loss: 4.611e+00| div_loss: 6.278e-01| %_mask_idx: 8.032e-02| ppl: 2.382e+02| lr: 2.570e-05| temp: 1.978e+00| grad_norm: 7.281e-01
# | loss: 4.692e+00| constrast_loss: 4.614e+00| div_loss: 7.792e-01| %_mask_idx: 4.016e-02| ppl: 1.413e+02| lr: 2.559e-05| temp: 1.977e+00| grad_norm: 7.390e-01
# | loss: 4.688e+00| constrast_loss: 4.612e+00| div_loss: 7.579e-01| %_mask_idx: 4.016e-02| ppl: 1.550e+02| lr: 2.548e-05| temp: 1.977e+00| grad_norm: 8.563e-01
# | loss: 4.698e+00| constrast_loss: 4.620e+00| div_loss: 7.738e-01| %_mask_idx: 4.016e-02| ppl: 1.448e+02| lr: 2.538e-05| temp: 1.977e+00| grad_norm: 7.427e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.731e-01| %_mask_idx: 4.016e-02| ppl: 1.452e+02| lr: 2.527e-05| temp: 1.977e+00| grad_norm: 8.384e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.562e-01| %_mask_idx: 4.016e-02| ppl: 1.561e+02| lr: 2.516e-05| temp: 1.977e+00| grad_norm: 7.010e-01
# | loss: 4.691e+00| constrast_loss: 4.617e+00| div_loss: 7.479e-01| %_mask_idx: 4.016e-02| ppl: 1.614e+02| lr: 2.505e-05| temp: 1.977e+00| grad_norm: 7.586e-01
# | loss: 4.688e+00| constrast_loss: 4.612e+00| div_loss: 7.601e-01| %_mask_idx: 4.016e-02| ppl: 1.536e+02| lr: 2.495e-05| temp: 1.977e+00| grad_norm: 6.724e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.778e-01| %_mask_idx: 4.016e-02| ppl: 1.422e+02| lr: 2.484e-05| temp: 1.977e+00| grad_norm: 7.829e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.652e-01| %_mask_idx: 4.016e-02| ppl: 1.502e+02| lr: 2.473e-05| temp: 1.977e+00| grad_norm: 7.209e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.748e-01| %_mask_idx: 4.016e-02| ppl: 1.441e+02| lr: 2.462e-05| temp: 1.977e+00| grad_norm: 7.250e-01
# | loss: 4.690e+00| constrast_loss: 4.612e+00| div_loss: 7.810e-01| %_mask_idx: 4.016e-02| ppl: 1.402e+02| lr: 2.452e-05| temp: 1.976e+00| grad_norm: 8.034e-01
# | loss: 4.693e+00| constrast_loss: 4.618e+00| div_loss: 7.518e-01| %_mask_idx: 4.016e-02| ppl: 1.588e+02| lr: 2.441e-05| temp: 1.976e+00| grad_norm: 8.490e-01
# | loss: 4.692e+00| constrast_loss: 4.614e+00| div_loss: 7.851e-01| %_mask_idx: 4.016e-02| ppl: 1.375e+02| lr: 2.430e-05| temp: 1.976e+00| grad_norm: 6.758e-01
# | loss: 4.694e+00| constrast_loss: 4.619e+00| div_loss: 7.468e-01| %_mask_idx: 4.016e-02| ppl: 1.620e+02| lr: 2.419e-05| temp: 1.976e+00| grad_norm: 8.167e-01
# | loss: 4.694e+00| constrast_loss: 4.618e+00| div_loss: 7.592e-01| %_mask_idx: 4.016e-02| ppl: 1.541e+02| lr: 2.409e-05| temp: 1.976e+00| grad_norm: 8.021e-01
# | loss: 4.690e+00| constrast_loss: 4.612e+00| div_loss: 7.752e-01| %_mask_idx: 4.016e-02| ppl: 1.438e+02| lr: 2.398e-05| temp: 1.976e+00| grad_norm: 7.588e-01
# | loss: 4.672e+00| constrast_loss: 4.610e+00| div_loss: 6.190e-01| %_mask_idx: 7.831e-02| ppl: 2.438e+02| lr: 2.387e-05| temp: 1.976e+00| grad_norm: 6.096e-01
# | loss: 4.676e+00| constrast_loss: 4.613e+00| div_loss: 6.334e-01| %_mask_idx: 8.032e-02| ppl: 2.346e+02| lr: 2.376e-05| temp: 1.976e+00| grad_norm: 6.219e-01
# | loss: 4.693e+00| constrast_loss: 4.617e+00| div_loss: 7.522e-01| %_mask_idx: 4.016e-02| ppl: 1.586e+02| lr: 2.366e-05| temp: 1.976e+00| grad_norm: 7.326e-01
# | loss: 4.683e+00| constrast_loss: 4.620e+00| div_loss: 6.265e-01| %_mask_idx: 7.681e-02| ppl: 2.391e+02| lr: 2.355e-05| temp: 1.976e+00| grad_norm: 7.538e-01
# | loss: 4.672e+00| constrast_loss: 4.614e+00| div_loss: 5.836e-01| %_mask_idx: 8.032e-02| ppl: 2.665e+02| lr: 2.344e-05| temp: 1.975e+00| grad_norm: 6.836e-01
# | loss: 4.690e+00| constrast_loss: 4.614e+00| div_loss: 7.606e-01| %_mask_idx: 4.016e-02| ppl: 1.532e+02| lr: 2.333e-05| temp: 1.975e+00| grad_norm: 8.323e-01
# | loss: 4.679e+00| constrast_loss: 4.615e+00| div_loss: 6.430e-01| %_mask_idx: 8.032e-02| ppl: 2.285e+02| lr: 2.323e-05| temp: 1.975e+00| grad_norm: 6.107e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.552e-01| %_mask_idx: 4.016e-02| ppl: 1.567e+02| lr: 2.312e-05| temp: 1.975e+00| grad_norm: 6.528e-01
# | loss: 4.684e+00| constrast_loss: 4.606e+00| div_loss: 7.793e-01| %_mask_idx: 4.016e-02| ppl: 1.413e+02| lr: 2.301e-05| temp: 1.975e+00| grad_norm: 7.331e-01
# | loss: 4.683e+00| constrast_loss: 4.607e+00| div_loss: 7.613e-01| %_mask_idx: 4.016e-02| ppl: 1.528e+02| lr: 2.290e-05| temp: 1.975e+00| grad_norm: 8.825e-01
# | loss: 4.695e+00| constrast_loss: 4.618e+00| div_loss: 7.674e-01| %_mask_idx: 4.016e-02| ppl: 1.489e+02| lr: 2.280e-05| temp: 1.975e+00| grad_norm: 7.506e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.657e-01| %_mask_idx: 4.016e-02| ppl: 1.499e+02| lr: 2.269e-05| temp: 1.975e+00| grad_norm: 5.731e-01
# | loss: 4.691e+00| constrast_loss: 4.613e+00| div_loss: 7.761e-01| %_mask_idx: 4.016e-02| ppl: 1.433e+02| lr: 2.258e-05| temp: 1.975e+00| grad_norm: 6.144e-01
# | loss: 4.692e+00| constrast_loss: 4.614e+00| div_loss: 7.745e-01| %_mask_idx: 4.016e-02| ppl: 1.443e+02| lr: 2.247e-05| temp: 1.975e+00| grad_norm: 8.106e-01
# | loss: 4.668e+00| constrast_loss: 4.610e+00| div_loss: 5.801e-01| %_mask_idx: 7.580e-02| ppl: 2.687e+02| lr: 2.237e-05| temp: 1.974e+00| grad_norm: 6.854e-01
# | loss: 4.671e+00| constrast_loss: 4.609e+00| div_loss: 6.205e-01| %_mask_idx: 8.032e-02| ppl: 2.429e+02| lr: 2.226e-05| temp: 1.974e+00| grad_norm: 7.674e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.635e-01| %_mask_idx: 4.016e-02| ppl: 1.513e+02| lr: 2.215e-05| temp: 1.974e+00| grad_norm: 7.193e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.623e-01| %_mask_idx: 4.016e-02| ppl: 1.521e+02| lr: 2.204e-05| temp: 1.974e+00| grad_norm: 6.777e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.729e-01| %_mask_idx: 4.016e-02| ppl: 1.453e+02| lr: 2.194e-05| temp: 1.974e+00| grad_norm: 6.562e-01
# | loss: 4.673e+00| constrast_loss: 4.610e+00| div_loss: 6.287e-01| %_mask_idx: 8.032e-02| ppl: 2.376e+02| lr: 2.183e-05| temp: 1.974e+00| grad_norm: 6.052e-01
# | loss: 4.676e+00| constrast_loss: 4.613e+00| div_loss: 6.253e-01| %_mask_idx: 8.032e-02| ppl: 2.398e+02| lr: 2.172e-05| temp: 1.974e+00| grad_norm: 6.805e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.652e-01| %_mask_idx: 4.016e-02| ppl: 1.503e+02| lr: 2.161e-05| temp: 1.974e+00| grad_norm: 6.373e-01
# | loss: 4.686e+00| constrast_loss: 4.610e+00| div_loss: 7.613e-01| %_mask_idx: 4.016e-02| ppl: 1.527e+02| lr: 2.151e-05| temp: 1.974e+00| grad_norm: 7.821e-01
# | loss: 4.695e+00| constrast_loss: 4.619e+00| div_loss: 7.564e-01| %_mask_idx: 4.016e-02| ppl: 1.559e+02| lr: 2.140e-05| temp: 1.974e+00| grad_norm: 8.045e-01
# | loss: 4.674e+00| constrast_loss: 4.616e+00| div_loss: 5.791e-01| %_mask_idx: 8.032e-02| ppl: 2.694e+02| lr: 2.129e-05| temp: 1.973e+00| grad_norm: 7.338e-01
# | loss: 4.677e+00| constrast_loss: 4.616e+00| div_loss: 6.041e-01| %_mask_idx: 8.032e-02| ppl: 2.534e+02| lr: 2.118e-05| temp: 1.973e+00| grad_norm: 6.667e-01
# | loss: 4.696e+00| constrast_loss: 4.619e+00| div_loss: 7.618e-01| %_mask_idx: 4.016e-02| ppl: 1.525e+02| lr: 2.108e-05| temp: 1.973e+00| grad_norm: 7.954e-01
# | loss: 4.675e+00| constrast_loss: 4.615e+00| div_loss: 5.982e-01| %_mask_idx: 8.032e-02| ppl: 2.572e+02| lr: 2.097e-05| temp: 1.973e+00| grad_norm: 7.655e-01
# | loss: 4.688e+00| constrast_loss: 4.614e+00| div_loss: 7.392e-01| %_mask_idx: 4.016e-02| ppl: 1.669e+02| lr: 2.086e-05| temp: 1.973e+00| grad_norm: 7.644e-01
# | loss: 4.679e+00| constrast_loss: 4.617e+00| div_loss: 6.159e-01| %_mask_idx: 8.032e-02| ppl: 2.459e+02| lr: 2.075e-05| temp: 1.973e+00| grad_norm: 7.400e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.741e-01| %_mask_idx: 4.016e-02| ppl: 1.445e+02| lr: 2.065e-05| temp: 1.973e+00| grad_norm: 5.978e-01
# | loss: 4.676e+00| constrast_loss: 4.617e+00| div_loss: 5.967e-01| %_mask_idx: 8.032e-02| ppl: 2.581e+02| lr: 2.054e-05| temp: 1.973e+00| grad_norm: 6.677e-01
# | loss: 4.675e+00| constrast_loss: 4.615e+00| div_loss: 6.011e-01| %_mask_idx: 8.032e-02| ppl: 2.553e+02| lr: 2.043e-05| temp: 1.973e+00| grad_norm: 6.430e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.503e-01| %_mask_idx: 4.016e-02| ppl: 1.598e+02| lr: 2.032e-05| temp: 1.973e+00| grad_norm: 8.020e-01
# | loss: 4.687e+00| constrast_loss: 4.610e+00| div_loss: 7.663e-01| %_mask_idx: 4.016e-02| ppl: 1.496e+02| lr: 2.022e-05| temp: 1.973e+00| grad_norm: 6.783e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.680e-01| %_mask_idx: 4.016e-02| ppl: 1.485e+02| lr: 2.011e-05| temp: 1.972e+00| grad_norm: 6.961e-01
# | loss: 4.687e+00| constrast_loss: 4.621e+00| div_loss: 6.667e-01| %_mask_idx: 4.016e-02| ppl: 2.133e+02| lr: 2.000e-05| temp: 1.972e+00| grad_norm: 7.238e-01
# | loss: 4.685e+00| constrast_loss: 4.608e+00| div_loss: 7.782e-01| %_mask_idx: 4.016e-02| ppl: 1.419e+02| lr: 1.989e-05| temp: 1.972e+00| grad_norm: 6.116e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.617e-01| %_mask_idx: 4.016e-02| ppl: 1.525e+02| lr: 1.978e-05| temp: 1.972e+00| grad_norm: 6.609e-01
# | loss: 4.694e+00| constrast_loss: 4.618e+00| div_loss: 7.543e-01| %_mask_idx: 4.016e-02| ppl: 1.573e+02| lr: 1.968e-05| temp: 1.972e+00| grad_norm: 7.317e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.517e-01| %_mask_idx: 4.016e-02| ppl: 1.589e+02| lr: 1.957e-05| temp: 1.972e+00| grad_norm: 6.787e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.497e-01| %_mask_idx: 4.016e-02| ppl: 1.602e+02| lr: 1.946e-05| temp: 1.972e+00| grad_norm: 6.665e-01
# | loss: 4.686e+00| constrast_loss: 4.617e+00| div_loss: 6.868e-01| %_mask_idx: 4.016e-02| ppl: 2.004e+02| lr: 1.935e-05| temp: 1.972e+00| grad_norm: 8.557e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.625e-01| %_mask_idx: 4.016e-02| ppl: 1.520e+02| lr: 1.925e-05| temp: 1.972e+00| grad_norm: 6.682e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.510e-01| %_mask_idx: 4.016e-02| ppl: 1.593e+02| lr: 1.914e-05| temp: 1.972e+00| grad_norm: 8.127e-01
# | loss: 4.695e+00| constrast_loss: 4.620e+00| div_loss: 7.518e-01| %_mask_idx: 4.016e-02| ppl: 1.588e+02| lr: 1.903e-05| temp: 1.971e+00| grad_norm: 6.662e-01
# | loss: 4.673e+00| constrast_loss: 4.618e+00| div_loss: 5.477e-01| %_mask_idx: 7.882e-02| ppl: 2.895e+02| lr: 1.892e-05| temp: 1.971e+00| grad_norm: 7.125e-01
# | loss: 4.678e+00| constrast_loss: 4.615e+00| div_loss: 6.325e-01| %_mask_idx: 7.681e-02| ppl: 2.352e+02| lr: 1.882e-05| temp: 1.971e+00| grad_norm: 6.381e-01
# | loss: 4.692e+00| constrast_loss: 4.617e+00| div_loss: 7.502e-01| %_mask_idx: 4.016e-02| ppl: 1.599e+02| lr: 1.871e-05| temp: 1.971e+00| grad_norm: 7.219e-01
# | loss: 4.687e+00| constrast_loss: 4.611e+00| div_loss: 7.596e-01| %_mask_idx: 4.016e-02| ppl: 1.538e+02| lr: 1.860e-05| temp: 1.971e+00| grad_norm: 7.956e-01
# | loss: 4.693e+00| constrast_loss: 4.618e+00| div_loss: 7.529e-01| %_mask_idx: 4.016e-02| ppl: 1.582e+02| lr: 1.849e-05| temp: 1.971e+00| grad_norm: 7.585e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.706e-01| %_mask_idx: 4.016e-02| ppl: 1.468e+02| lr: 1.839e-05| temp: 1.971e+00| grad_norm: 6.816e-01
# | loss: 4.687e+00| constrast_loss: 4.613e+00| div_loss: 7.425e-01| %_mask_idx: 4.016e-02| ppl: 1.648e+02| lr: 1.828e-05| temp: 1.971e+00| grad_norm: 6.763e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.571e-01| %_mask_idx: 4.016e-02| ppl: 1.555e+02| lr: 1.817e-05| temp: 1.971e+00| grad_norm: 6.283e-01
# | loss: 4.678e+00| constrast_loss: 4.617e+00| div_loss: 6.144e-01| %_mask_idx: 7.631e-02| ppl: 2.468e+02| lr: 1.806e-05| temp: 1.971e+00| grad_norm: 6.292e-01
# | loss: 4.682e+00| constrast_loss: 4.615e+00| div_loss: 6.628e-01| %_mask_idx: 4.016e-02| ppl: 2.158e+02| lr: 1.796e-05| temp: 1.970e+00| grad_norm: 7.835e-01
# | loss: 4.685e+00| constrast_loss: 4.607e+00| div_loss: 7.819e-01| %_mask_idx: 4.016e-02| ppl: 1.396e+02| lr: 1.785e-05| temp: 1.970e+00| grad_norm: 7.237e-01
# | loss: 4.676e+00| constrast_loss: 4.616e+00| div_loss: 6.039e-01| %_mask_idx: 7.982e-02| ppl: 2.535e+02| lr: 1.774e-05| temp: 1.970e+00| grad_norm: 6.853e-01
# ...
# | loss: 4.694e+00| constrast_loss: 4.621e+00| div_loss: 7.222e-01| %_mask_idx: 4.016e-02| ppl: 1.778e+02| lr: 1.054e-05| temp: 1.964e+00| grad_norm: 8.022e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.528e-01| %_mask_idx: 4.016e-02| ppl: 1.582e+02| lr: 1.043e-05| temp: 1.964e+00| grad_norm: 7.533e-01
# | loss: 4.677e+00| constrast_loss: 4.615e+00| div_loss: 6.223e-01| %_mask_idx: 8.032e-02| ppl: 2.417e+02| lr: 1.032e-05| temp: 1.963e+00| grad_norm: 5.995e-01
# | loss: 4.680e+00| constrast_loss: 4.620e+00| div_loss: 6.080e-01| %_mask_idx: 7.681e-02| ppl: 2.509e+02| lr: 1.022e-05| temp: 1.963e+00| grad_norm: 7.587e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.623e-01| %_mask_idx: 4.016e-02| ppl: 1.521e+02| lr: 1.011e-05| temp: 1.963e+00| grad_norm: 7.126e-01
# | loss: 4.694e+00| constrast_loss: 4.618e+00| div_loss: 7.585e-01| %_mask_idx: 4.016e-02| ppl: 1.546e+02| lr: 1.000e-05| temp: 1.963e+00| grad_norm: 7.101e-01
# | loss: 4.692e+00| constrast_loss: 4.615e+00| div_loss: 7.671e-01| %_mask_idx: 4.016e-02| ppl: 1.490e+02| lr: 9.892e-06| temp: 1.963e+00| grad_norm: 7.911e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.518e-01| %_mask_idx: 4.016e-02| ppl: 1.588e+02| lr: 9.785e-06| temp: 1.963e+00| grad_norm: 7.519e-01
# | loss: 4.675e+00| constrast_loss: 4.614e+00| div_loss: 6.059e-01| %_mask_idx: 8.032e-02| ppl: 2.522e+02| lr: 9.677e-06| temp: 1.963e+00| grad_norm: 7.398e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.614e-01| %_mask_idx: 4.016e-02| ppl: 1.527e+02| lr: 9.570e-06| temp: 1.963e+00| grad_norm: 6.649e-01
# | loss: 4.689e+00| constrast_loss: 4.615e+00| div_loss: 7.414e-01| %_mask_idx: 4.016e-02| ppl: 1.655e+02| lr: 9.462e-06| temp: 1.963e+00| grad_norm: 7.450e-01
# | loss: 4.691e+00| constrast_loss: 4.617e+00| div_loss: 7.453e-01| %_mask_idx: 4.016e-02| ppl: 1.630e+02| lr: 9.355e-06| temp: 1.963e+00| grad_norm: 7.240e-01
# | loss: 4.677e+00| constrast_loss: 4.614e+00| div_loss: 6.286e-01| %_mask_idx: 8.032e-02| ppl: 2.377e+02| lr: 9.247e-06| temp: 1.962e+00| grad_norm: 7.133e-01
# | loss: 4.674e+00| constrast_loss: 4.612e+00| div_loss: 6.291e-01| %_mask_idx: 8.032e-02| ppl: 2.374e+02| lr: 9.140e-06| temp: 1.962e+00| grad_norm: 6.646e-01
# | loss: 4.676e+00| constrast_loss: 4.619e+00| div_loss: 5.700e-01| %_mask_idx: 8.032e-02| ppl: 2.752e+02| lr: 9.032e-06| temp: 1.962e+00| grad_norm: 7.526e-01
# | loss: 4.691e+00| constrast_loss: 4.616e+00| div_loss: 7.480e-01| %_mask_idx: 4.016e-02| ppl: 1.613e+02| lr: 8.925e-06| temp: 1.962e+00| grad_norm: 6.945e-01
# | loss: 4.685e+00| constrast_loss: 4.608e+00| div_loss: 7.671e-01| %_mask_idx: 4.016e-02| ppl: 1.491e+02| lr: 8.817e-06| temp: 1.962e+00| grad_norm: 7.214e-01
# | loss: 4.692e+00| constrast_loss: 4.617e+00| div_loss: 7.594e-01| %_mask_idx: 4.016e-02| ppl: 1.540e+02| lr: 8.710e-06| temp: 1.962e+00| grad_norm: 7.360e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.605e-01| %_mask_idx: 4.016e-02| ppl: 1.533e+02| lr: 8.602e-06| temp: 1.962e+00| grad_norm: 6.357e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.584e-01| %_mask_idx: 4.016e-02| ppl: 1.546e+02| lr: 8.495e-06| temp: 1.962e+00| grad_norm: 8.302e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.496e-01| %_mask_idx: 4.016e-02| ppl: 1.603e+02| lr: 8.387e-06| temp: 1.962e+00| grad_norm: 6.740e-01
# | loss: 4.673e+00| constrast_loss: 4.614e+00| div_loss: 5.920e-01| %_mask_idx: 7.781e-02| ppl: 2.611e+02| lr: 8.280e-06| temp: 1.962e+00| grad_norm: 6.830e-01
# | loss: 4.686e+00| constrast_loss: 4.610e+00| div_loss: 7.627e-01| %_mask_idx: 4.016e-02| ppl: 1.519e+02| lr: 8.172e-06| temp: 1.961e+00| grad_norm: 7.100e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.513e-01| %_mask_idx: 4.016e-02| ppl: 1.591e+02| lr: 8.065e-06| temp: 1.961e+00| grad_norm: 7.569e-01
# | loss: 4.676e+00| constrast_loss: 4.616e+00| div_loss: 6.013e-01| %_mask_idx: 8.032e-02| ppl: 2.552e+02| lr: 7.957e-06| temp: 1.961e+00| grad_norm: 7.172e-01
# | loss: 4.694e+00| constrast_loss: 4.617e+00| div_loss: 7.685e-01| %_mask_idx: 4.016e-02| ppl: 1.481e+02| lr: 7.849e-06| temp: 1.961e+00| grad_norm: 7.539e-01
# | loss: 4.687e+00| constrast_loss: 4.614e+00| div_loss: 7.333e-01| %_mask_idx: 4.016e-02| ppl: 1.707e+02| lr: 7.742e-06| temp: 1.961e+00| grad_norm: 8.640e-01
# | loss: 4.687e+00| constrast_loss: 4.614e+00| div_loss: 7.381e-01| %_mask_idx: 4.016e-02| ppl: 1.676e+02| lr: 7.634e-06| temp: 1.961e+00| grad_norm: 7.580e-01
# | loss: 4.671e+00| constrast_loss: 4.613e+00| div_loss: 5.860e-01| %_mask_idx: 8.032e-02| ppl: 2.649e+02| lr: 7.527e-06| temp: 1.961e+00| grad_norm: 7.838e-01
# | loss: 4.672e+00| constrast_loss: 4.612e+00| div_loss: 5.970e-01| %_mask_idx: 4.016e-02| ppl: 2.579e+02| lr: 7.419e-06| temp: 1.961e+00| grad_norm: 7.742e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.480e-01| %_mask_idx: 4.016e-02| ppl: 1.613e+02| lr: 7.312e-06| temp: 1.961e+00| grad_norm: 7.345e-01
# | loss: 4.691e+00| constrast_loss: 4.618e+00| div_loss: 7.353e-01| %_mask_idx: 4.016e-02| ppl: 1.694e+02| lr: 7.204e-06| temp: 1.961e+00| grad_norm: 6.838e-01
# | loss: 4.686e+00| constrast_loss: 4.610e+00| div_loss: 7.675e-01| %_mask_idx: 4.016e-02| ppl: 1.488e+02| lr: 7.097e-06| temp: 1.961e+00| grad_norm: 6.910e-01
# | loss: 4.689e+00| constrast_loss: 4.615e+00| div_loss: 7.399e-01| %_mask_idx: 4.016e-02| ppl: 1.665e+02| lr: 6.989e-06| temp: 1.960e+00| grad_norm: 8.012e-01
# | loss: 4.679e+00| constrast_loss: 4.602e+00| div_loss: 7.721e-01| %_mask_idx: 4.016e-02| ppl: 1.459e+02| lr: 6.882e-06| temp: 1.960e+00| grad_norm: 6.280e-01
# | loss: 4.690e+00| constrast_loss: 4.613e+00| div_loss: 7.670e-01| %_mask_idx: 4.016e-02| ppl: 1.491e+02| lr: 6.774e-06| temp: 1.960e+00| grad_norm: 6.775e-01
# | loss: 4.686e+00| constrast_loss: 4.610e+00| div_loss: 7.599e-01| %_mask_idx: 4.016e-02| ppl: 1.537e+02| lr: 6.667e-06| temp: 1.960e+00| grad_norm: 7.851e-01
# | loss: 4.694e+00| constrast_loss: 4.618e+00| div_loss: 7.651e-01| %_mask_idx: 4.016e-02| ppl: 1.503e+02| lr: 6.559e-06| temp: 1.960e+00| grad_norm: 6.961e-01
# | loss: 4.692e+00| constrast_loss: 4.618e+00| div_loss: 7.369e-01| %_mask_idx: 4.016e-02| ppl: 1.684e+02| lr: 6.452e-06| temp: 1.960e+00| grad_norm: 7.039e-01
# | loss: 4.690e+00| constrast_loss: 4.616e+00| div_loss: 7.366e-01| %_mask_idx: 4.016e-02| ppl: 1.686e+02| lr: 6.344e-06| temp: 1.960e+00| grad_norm: 7.552e-01
# | loss: 4.693e+00| constrast_loss: 4.617e+00| div_loss: 7.528e-01| %_mask_idx: 4.016e-02| ppl: 1.582e+02| lr: 6.237e-06| temp: 1.960e+00| grad_norm: 6.517e-01
# | loss: 4.691e+00| constrast_loss: 4.615e+00| div_loss: 7.570e-01| %_mask_idx: 4.016e-02| ppl: 1.555e+02| lr: 6.129e-06| temp: 1.960e+00| grad_norm: 6.644e-01
# | loss: 4.687e+00| constrast_loss: 4.614e+00| div_loss: 7.363e-01| %_mask_idx: 4.016e-02| ppl: 1.688e+02| lr: 6.022e-06| temp: 1.960e+00| grad_norm: 6.897e-01
# | loss: 4.684e+00| constrast_loss: 4.612e+00| div_loss: 7.167e-01| %_mask_idx: 4.016e-02| ppl: 1.813e+02| lr: 5.914e-06| temp: 1.959e+00| grad_norm: 7.358e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.493e-01| %_mask_idx: 4.016e-02| ppl: 1.605e+02| lr: 5.806e-06| temp: 1.959e+00| grad_norm: 7.325e-01
# | loss: 4.676e+00| constrast_loss: 4.617e+00| div_loss: 5.884e-01| %_mask_idx: 8.032e-02| ppl: 2.634e+02| lr: 5.699e-06| temp: 1.959e+00| grad_norm: 7.672e-01
# | loss: 4.689e+00| constrast_loss: 4.610e+00| div_loss: 7.875e-01| %_mask_idx: 4.016e-02| ppl: 1.360e+02| lr: 5.591e-06| temp: 1.959e+00| grad_norm: 8.076e-01
# | loss: 4.688e+00| constrast_loss: 4.612e+00| div_loss: 7.618e-01| %_mask_idx: 4.016e-02| ppl: 1.524e+02| lr: 5.484e-06| temp: 1.959e+00| grad_norm: 7.317e-01
# | loss: 4.688e+00| constrast_loss: 4.615e+00| div_loss: 7.293e-01| %_mask_idx: 4.016e-02| ppl: 1.733e+02| lr: 5.376e-06| temp: 1.959e+00| grad_norm: 7.345e-01
# | loss: 4.693e+00| constrast_loss: 4.618e+00| div_loss: 7.492e-01| %_mask_idx: 4.016e-02| ppl: 1.605e+02| lr: 5.269e-06| temp: 1.959e+00| grad_norm: 7.695e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.430e-01| %_mask_idx: 4.016e-02| ppl: 1.645e+02| lr: 5.161e-06| temp: 1.959e+00| grad_norm: 8.120e-01
# | loss: 4.676e+00| constrast_loss: 4.618e+00| div_loss: 5.829e-01| %_mask_idx: 8.032e-02| ppl: 2.669e+02| lr: 5.054e-06| temp: 1.959e+00| grad_norm: 6.639e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.565e-01| %_mask_idx: 4.016e-02| ppl: 1.558e+02| lr: 4.946e-06| temp: 1.959e+00| grad_norm: 6.854e-01
# | loss: 4.690e+00| constrast_loss: 4.616e+00| div_loss: 7.412e-01| %_mask_idx: 4.016e-02| ppl: 1.656e+02| lr: 4.839e-06| temp: 1.958e+00| grad_norm: 6.999e-01
# | loss: 4.674e+00| constrast_loss: 4.615e+00| div_loss: 5.878e-01| %_mask_idx: 7.932e-02| ppl: 2.638e+02| lr: 4.731e-06| temp: 1.958e+00| grad_norm: 6.778e-01
# | loss: 4.670e+00| constrast_loss: 4.611e+00| div_loss: 5.910e-01| %_mask_idx: 8.032e-02| ppl: 2.618e+02| lr: 4.624e-06| temp: 1.958e+00| grad_norm: 6.810e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.565e-01| %_mask_idx: 4.016e-02| ppl: 1.559e+02| lr: 4.516e-06| temp: 1.958e+00| grad_norm: 6.092e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.508e-01| %_mask_idx: 4.016e-02| ppl: 1.595e+02| lr: 4.409e-06| temp: 1.958e+00| grad_norm: 7.167e-01
# | loss: 4.675e+00| constrast_loss: 4.615e+00| div_loss: 5.955e-01| %_mask_idx: 7.681e-02| ppl: 2.589e+02| lr: 4.301e-06| temp: 1.958e+00| grad_norm: 8.242e-01
# | loss: 4.688e+00| constrast_loss: 4.613e+00| div_loss: 7.473e-01| %_mask_idx: 4.016e-02| ppl: 1.617e+02| lr: 4.194e-06| temp: 1.958e+00| grad_norm: 6.951e-01
# | loss: 4.685e+00| constrast_loss: 4.610e+00| div_loss: 7.526e-01| %_mask_idx: 4.016e-02| ppl: 1.584e+02| lr: 4.086e-06| temp: 1.958e+00| grad_norm: 7.215e-01
# | loss: 4.691e+00| constrast_loss: 4.614e+00| div_loss: 7.713e-01| %_mask_idx: 4.016e-02| ppl: 1.464e+02| lr: 3.978e-06| temp: 1.958e+00| grad_norm: 6.025e-01
# | loss: 4.685e+00| constrast_loss: 4.609e+00| div_loss: 7.550e-01| %_mask_idx: 4.016e-02| ppl: 1.568e+02| lr: 3.871e-06| temp: 1.958e+00| grad_norm: 6.862e-01
# | loss: 4.675e+00| constrast_loss: 4.615e+00| div_loss: 6.039e-01| %_mask_idx: 8.032e-02| ppl: 2.535e+02| lr: 3.763e-06| temp: 1.957e+00| grad_norm: 7.143e-01
# | loss: 4.679e+00| constrast_loss: 4.602e+00| div_loss: 7.737e-01| %_mask_idx: 4.016e-02| ppl: 1.448e+02| lr: 3.656e-06| temp: 1.957e+00| grad_norm: 7.165e-01
# | loss: 4.675e+00| constrast_loss: 4.613e+00| div_loss: 6.187e-01| %_mask_idx: 8.032e-02| ppl: 2.440e+02| lr: 3.548e-06| temp: 1.957e+00| grad_norm: 7.184e-01
# | loss: 4.672e+00| constrast_loss: 4.612e+00| div_loss: 5.962e-01| %_mask_idx: 7.831e-02| ppl: 2.584e+02| lr: 3.441e-06| temp: 1.957e+00| grad_norm: 8.233e-01
# | loss: 4.694e+00| constrast_loss: 4.618e+00| div_loss: 7.559e-01| %_mask_idx: 4.016e-02| ppl: 1.562e+02| lr: 3.333e-06| temp: 1.957e+00| grad_norm: 6.540e-01
# | loss: 4.686e+00| constrast_loss: 4.611e+00| div_loss: 7.522e-01| %_mask_idx: 4.016e-02| ppl: 1.586e+02| lr: 3.226e-06| temp: 1.957e+00| grad_norm: 7.996e-01
# | loss: 4.693e+00| constrast_loss: 4.617e+00| div_loss: 7.557e-01| %_mask_idx: 4.016e-02| ppl: 1.564e+02| lr: 3.118e-06| temp: 1.957e+00| grad_norm: 7.534e-01
# | loss: 4.688e+00| constrast_loss: 4.613e+00| div_loss: 7.509e-01| %_mask_idx: 4.016e-02| ppl: 1.594e+02| lr: 3.011e-06| temp: 1.957e+00| grad_norm: 6.833e-01
# | loss: 4.678e+00| constrast_loss: 4.619e+00| div_loss: 5.893e-01| %_mask_idx: 8.032e-02| ppl: 2.629e+02| lr: 2.903e-06| temp: 1.957e+00| grad_norm: 6.739e-01
# | loss: 4.690e+00| constrast_loss: 4.614e+00| div_loss: 7.603e-01| %_mask_idx: 4.016e-02| ppl: 1.534e+02| lr: 2.796e-06| temp: 1.957e+00| grad_norm: 7.042e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.582e-01| %_mask_idx: 4.016e-02| ppl: 1.548e+02| lr: 2.688e-06| temp: 1.956e+00| grad_norm: 8.018e-01
# | loss: 4.673e+00| constrast_loss: 4.611e+00| div_loss: 6.204e-01| %_mask_idx: 7.731e-02| ppl: 2.429e+02| lr: 2.581e-06| temp: 1.956e+00| grad_norm: 7.640e-01
# | loss: 4.689e+00| constrast_loss: 4.615e+00| div_loss: 7.377e-01| %_mask_idx: 4.016e-02| ppl: 1.679e+02| lr: 2.473e-06| temp: 1.956e+00| grad_norm: 7.384e-01
# | loss: 4.685e+00| constrast_loss: 4.610e+00| div_loss: 7.517e-01| %_mask_idx: 4.016e-02| ppl: 1.589e+02| lr: 2.366e-06| temp: 1.956e+00| grad_norm: 7.430e-01
# | loss: 4.685e+00| constrast_loss: 4.612e+00| div_loss: 7.343e-01| %_mask_idx: 4.016e-02| ppl: 1.701e+02| lr: 2.258e-06| temp: 1.956e+00| grad_norm: 7.270e-01
# | loss: 4.688e+00| constrast_loss: 4.613e+00| div_loss: 7.456e-01| %_mask_idx: 4.016e-02| ppl: 1.628e+02| lr: 2.151e-06| temp: 1.956e+00| grad_norm: 6.411e-01
# | loss: 4.672e+00| constrast_loss: 4.614e+00| div_loss: 5.845e-01| %_mask_idx: 8.032e-02| ppl: 2.659e+02| lr: 2.043e-06| temp: 1.956e+00| grad_norm: 7.711e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.416e-01| %_mask_idx: 4.016e-02| ppl: 1.654e+02| lr: 1.935e-06| temp: 1.956e+00| grad_norm: 7.466e-01
# | loss: 4.688e+00| constrast_loss: 4.615e+00| div_loss: 7.270e-01| %_mask_idx: 4.016e-02| ppl: 1.747e+02| lr: 1.828e-06| temp: 1.956e+00| grad_norm: 8.125e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.451e-01| %_mask_idx: 4.016e-02| ppl: 1.631e+02| lr: 1.720e-06| temp: 1.956e+00| grad_norm: 6.815e-01
# | loss: 4.685e+00| constrast_loss: 4.608e+00| div_loss: 7.630e-01| %_mask_idx: 4.016e-02| ppl: 1.517e+02| lr: 1.613e-06| temp: 1.956e+00| grad_norm: 6.570e-01
# | loss: 4.689e+00| constrast_loss: 4.614e+00| div_loss: 7.515e-01| %_mask_idx: 4.016e-02| ppl: 1.591e+02| lr: 1.505e-06| temp: 1.955e+00| grad_norm: 7.197e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.581e-01| %_mask_idx: 4.016e-02| ppl: 1.548e+02| lr: 1.398e-06| temp: 1.955e+00| grad_norm: 7.193e-01
# | loss: 4.674e+00| constrast_loss: 4.612e+00| div_loss: 6.158e-01| %_mask_idx: 7.580e-02| ppl: 2.459e+02| lr: 1.290e-06| temp: 1.955e+00| grad_norm: 6.561e-01
# | loss: 4.690e+00| constrast_loss: 4.615e+00| div_loss: 7.471e-01| %_mask_idx: 4.016e-02| ppl: 1.619e+02| lr: 1.183e-06| temp: 1.955e+00| grad_norm: 6.815e-01
# | loss: 4.688e+00| constrast_loss: 4.610e+00| div_loss: 7.807e-01| %_mask_idx: 4.016e-02| ppl: 1.404e+02| lr: 1.075e-06| temp: 1.955e+00| grad_norm: 7.001e-01
# | loss: 4.685e+00| constrast_loss: 4.611e+00| div_loss: 7.423e-01| %_mask_idx: 4.016e-02| ppl: 1.650e+02| lr: 9.677e-07| temp: 1.955e+00| grad_norm: 8.262e-01
# | loss: 4.676e+00| constrast_loss: 4.614e+00| div_loss: 6.212e-01| %_mask_idx: 7.580e-02| ppl: 2.424e+02| lr: 8.602e-07| temp: 1.955e+00| grad_norm: 6.813e-01
# | loss: 4.692e+00| constrast_loss: 4.616e+00| div_loss: 7.615e-01| %_mask_idx: 4.016e-02| ppl: 1.526e+02| lr: 7.527e-07| temp: 1.955e+00| grad_norm: 6.028e-01
# | loss: 4.692e+00| constrast_loss: 4.617e+00| div_loss: 7.531e-01| %_mask_idx: 4.016e-02| ppl: 1.580e+02| lr: 6.452e-07| temp: 1.955e+00| grad_norm: 7.202e-01
# | loss: 4.672e+00| constrast_loss: 4.612e+00| div_loss: 6.039e-01| %_mask_idx: 8.032e-02| ppl: 2.535e+02| lr: 5.376e-07| temp: 1.955e+00| grad_norm: 7.010e-01
# | loss: 4.687e+00| constrast_loss: 4.612e+00| div_loss: 7.505e-01| %_mask_idx: 4.016e-02| ppl: 1.597e+02| lr: 4.301e-07| temp: 1.954e+00| grad_norm: 7.731e-01
# | loss: 4.675e+00| constrast_loss: 4.614e+00| div_loss: 6.129e-01| %_mask_idx: 7.631e-02| ppl: 2.477e+02| lr: 3.226e-07| temp: 1.954e+00| grad_norm: 6.727e-01
# | loss: 4.690e+00| constrast_loss: 4.614e+00| div_loss: 7.637e-01| %_mask_idx: 4.016e-02| ppl: 1.513e+02| lr: 2.151e-07| temp: 1.954e+00| grad_norm: 7.052e-01
# | loss: 4.687e+00| constrast_loss: 4.611e+00| div_loss: 7.601e-01| %_mask_idx: 4.016e-02| ppl: 1.535e+02| lr: 1.075e-07| temp: 1.954e+00| grad_norm: 7.615e-01
# | loss: 4.689e+00| constrast_loss: 4.613e+00| div_loss: 7.631e-01| %_mask_idx: 4.016e-02| ppl: 1.516e+02| lr: 0.000e+00| temp: 1.954e+00| grad_norm: 6.203e-01
# | val_loss: 4.674e+00| val_contrastive_loss: 4.598e+00| val_diversity_loss: 7.555e-01| val_num_losses: 1.000e+00

# %%
writer.close()
